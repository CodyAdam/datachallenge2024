# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import MinMaxScaler
from sklearn.ensemble import RandomForestRegressor
from sklearn.model_selection import train_test_split
from tensorflow.keras.models import Sequential, Model
from tensorflow.keras.layers import LSTM, Dense, Input
import matplotlib.pyplot as plt

from sklearn.metrics import mean_squared_error, mean_absolute_error
import math
# Out:
# 2024-01-20 11:03:42.819558: I external/local_tsl/tsl/cuda/cudart_stub.cc:31] Could not find cuda drivers on your machine, GPU will not be used.
# 2024-01-20 11:03:42.855594: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-01-20 11:03:42.855619: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-01-20 11:03:42.856472: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-01-20 11:03:42.861871: I external/local_tsl/tsl/cuda/cudart_stub.cc:31] Could not find cuda drivers on your machine, GPU will not be used.
# 2024-01-20 11:03:42.862469: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2024-01-20 11:03:43.677152: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT

# %%
CLOSE = "Close_ETH"

# %%
file_path = '../data/federalfinancegestion/Rennes_DataChallenge2024_Cryptomarkets_dataset.xlsx'
data = pd.read_excel(file_path)

# Remove all string (object type) columns from the dataset
data_numeric = data.select_dtypes(exclude=['object'])

# Finding the column that closely matches "Close_BTC" in the numeric dataset
close_btc_column_numeric = [col for col in data_numeric.columns if "Close_BTC" in col]

close_btc_column_numeric = close_btc_column_numeric[0]
# Calculate the correlation of all columns with Close_BTC in the numeric dataset
correlation_with_close_btc_numeric = data_numeric.corr()[close_btc_column_numeric].sort_values(ascending=False)

# Extract the top 10 most correlated feature names
top_feature = correlation_with_close_btc_numeric.head(10).index.tolist()
include = top_feature

# %%
# Load data
dataset_pickle = '../data/federalfinancegestion/dataset.pkl'
df = pd.read_pickle(dataset_pickle)
df.fillna(0, inplace=True)
df['date'] = pd.to_datetime(df['date'])
df.set_index('date', inplace=True)

start_date_training = pd.to_datetime('2017-08-01')
end_date_training = pd.to_datetime('2022-08-31')
start_date_testing = pd.to_datetime('2022-09-01')
end_date_testing = pd.to_datetime('2023-04-30')

# %%
train_df = df.loc[start_date_training:end_date_training]
test_df = df.loc[start_date_testing:end_date_testing]

# %%
# Calculating the logarithmic difference of 'Close'
df['Close_Log'] = np.log(df[CLOSE])  # First, compute the log of 'Close'
df['Log_Diff_Close'] = df['Close_Log'].diff().fillna(0)  # Then compute the difference and handle NaN

# %%
# Include features
train = train_df[include].values
test = test_df[include].values

# %%
# Normalize the data
scaler = MinMaxScaler(feature_range=(0, 1))
train_scaled = scaler.fit_transform(train)
test_scaled = scaler.transform(test)

# %%
# # # SDAE
input_layer = Input(shape=(len(include),))
encoded = Dense(64, activation='relu')(input_layer)
encoded = Dense(32, activation='relu')(encoded)
encoded = Dense(16, activation='relu')(encoded)

decoded = Dense(32, activation='relu')(encoded)
decoded = Dense(64, activation='relu')(decoded)
decoded = Dense(len(include), activation='sigmoid')(decoded)

autoencoder = Model(input_layer, decoded)
autoencoder.compile(optimizer='adam', loss='mse')

# Train the autoencoder
autoencoder.fit(train_scaled, train_scaled, epochs=150, batch_size=32, shuffle=True, validation_split=0.2)

# Get the encoded representation of the data
encoded_features = autoencoder.predict(train_scaled)

def create_sequences(data, sequence_length):
    xs, ys = [], []
    for i in range(len(data) - sequence_length):
        x = data[i:(i + sequence_length), :]
        y = data[i + sequence_length, 0]
        xs.append(x)
        ys.append(y)
    return np.array(xs), np.array(ys)

sequence_length = 5  # Number of days used to predict the next day
X_train, y_train = create_sequences(train_scaled, sequence_length)
X_test, y_test = create_sequences(test_scaled, sequence_length)

# Reshape inputs for LSTM [samples, time steps, features]
X_train = np.reshape(X_train, (X_train.shape[0], X_train.shape[1], len(include)))
X_test = np.reshape(X_test, (X_test.shape[0], X_test.shape[1], len(include)))
# Out:
# Epoch 1/150
# 2024-01-20 11:03:48.307369: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:901] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-01-20 11:03:48.307804: W tensorflow/core/common_runtime/gpu/gpu_device.cc:2256] Cannot dlopen some GPU libraries. Please make sure the missing libraries mentioned above are installed properly if you would like to use GPU. Follow the guide at https://www.tensorflow.org/install/gpu for how to download and setup the required libraries for your platform.
# Skipping registering GPU devices...
# 33/33 [==============================] - 1s 6ms/step - loss: 0.1264 - val_loss: 0.0699
# Epoch 2/150
# 33/33 [==============================] - 0s 2ms/step - loss: 0.0358 - val_loss: 0.0551
# Epoch 3/150
# 33/33 [==============================] - 0s 3ms/step - loss: 0.0113 - val_loss: 0.0225
# Epoch 4/150
# 33/33 [==============================] - 0s 2ms/step - loss: 0.0063 - val_loss: 0.0178
# Epoch 5/150
# 33/33 [==============================] - 0s 2ms/step - loss: 0.0047 - val_loss: 0.0155
# Epoch 6/150
# 33/33 [==============================] - 0s 2ms/step - loss: 0.0041 - val_loss: 0.0160
# Epoch 7/150
# 33/33 [==============================] - 0s 2ms/step - loss: 0.0038 - val_loss: 0.0153
# Epoch 8/150
# 33/33 [==============================] - 0s 2ms/step - loss: 0.0035 - val_loss: 0.0147
# Epoch 9/150
# 33/33 [==============================] - 0s 2ms/step - loss: 0.0033 - val_loss: 0.0141
# Epoch 10/150
# 33/33 [==============================] - 0s 2ms/step - loss: 0.0031 - val_loss: 0.0147
# Epoch 11/150
# 33/33 [==============================] - 0s 2ms/step - loss: 0.0027 - val_loss: 0.0128
# Epoch 12/150
# 33/33 [==============================] - 0s 2ms/step - loss: 0.0023 - val_loss: 0.0131
# Epoch 13/150
# 33/33 [==============================] - 0s 2ms/step - loss: 0.0019 - val_loss: 0.0124
# Epoch 14/150
# 33/33 [==============================] - 0s 2ms/step - loss: 0.0016 - val_loss: 0.0127
# Epoch 15/150
# 33/33 [==============================] - 0s 2ms/step - loss: 0.0014 - val_loss: 0.0117
# Epoch 16/150
# 33/33 [==============================] - 0s 2ms/step - loss: 0.0012 - val_loss: 0.0119
# Epoch 17/150
# 33/33 [==============================] - 0s 2ms/step - loss: 0.0012 - val_loss: 0.0108
# Epoch 18/150
# 33/33 [==============================] - 0s 2ms/step - loss: 0.0011 - val_loss: 0.0117
# Epoch 19/150
# 33/33 [==============================] - 0s 2ms/step - loss: 0.0011 - val_loss: 0.0103
# Epoch 20/150
# 33/33 [==============================] - 0s 2ms/step - loss: 0.0010 - val_loss: 0.0111
# Epoch 21/150
# 33/33 [==============================] - 0s 2ms/step - loss: 9.6413e-04 - val_loss: 0.0106
# Epoch 22/150
# 33/33 [==============================] - 0s 2ms/step - loss: 9.1664e-04 - val_loss: 0.0098
# Epoch 23/150
# 33/33 [==============================] - 0s 2ms/step - loss: 8.6853e-04 - val_loss: 0.0100
# Epoch 24/150
# 33/33 [==============================] - 0s 2ms/step - loss: 8.3891e-04 - val_loss: 0.0101
# Epoch 25/150
# 33/33 [==============================] - 0s 2ms/step - loss: 7.6924e-04 - val_loss: 0.0105
# Epoch 26/150
# 33/33 [==============================] - 0s 2ms/step - loss: 7.1400e-04 - val_loss: 0.0096
# Epoch 27/150
# 33/33 [==============================] - 0s 2ms/step - loss: 6.6159e-04 - val_loss: 0.0101
# Epoch 28/150
# 33/33 [==============================] - 0s 2ms/step - loss: 6.2528e-04 - val_loss: 0.0088
# Epoch 29/150
# 33/33 [==============================] - 0s 2ms/step - loss: 5.6559e-04 - val_loss: 0.0098
# Epoch 30/150
# 33/33 [==============================] - 0s 2ms/step - loss: 5.2346e-04 - val_loss: 0.0089
# Epoch 31/150
# 33/33 [==============================] - 0s 2ms/step - loss: 5.0861e-04 - val_loss: 0.0084
# Epoch 32/150
# 33/33 [==============================] - 0s 2ms/step - loss: 4.8424e-04 - val_loss: 0.0084
# Epoch 33/150
# 33/33 [==============================] - 0s 2ms/step - loss: 5.0394e-04 - val_loss: 0.0085
# Epoch 34/150
# 33/33 [==============================] - 0s 2ms/step - loss: 4.6424e-04 - val_loss: 0.0087
# Epoch 35/150
# 33/33 [==============================] - 0s 2ms/step - loss: 4.3764e-04 - val_loss: 0.0088
# Epoch 36/150
# 33/33 [==============================] - 0s 2ms/step - loss: 4.1811e-04 - val_loss: 0.0083
# Epoch 37/150
# 33/33 [==============================] - 0s 2ms/step - loss: 4.2613e-04 - val_loss: 0.0083
# Epoch 38/150
# 33/33 [==============================] - 0s 2ms/step - loss: 4.2177e-04 - val_loss: 0.0077
# Epoch 39/150
# 33/33 [==============================] - 0s 2ms/step - loss: 4.0680e-04 - val_loss: 0.0075
# Epoch 40/150
# 33/33 [==============================] - 0s 2ms/step - loss: 3.9753e-04 - val_loss: 0.0078
# Epoch 41/150
# 33/33 [==============================] - 0s 2ms/step - loss: 3.8861e-04 - val_loss: 0.0081
# Epoch 42/150
# 33/33 [==============================] - 0s 2ms/step - loss: 3.7585e-04 - val_loss: 0.0080
# Epoch 43/150
# 33/33 [==============================] - 0s 2ms/step - loss: 3.7270e-04 - val_loss: 0.0070
# Epoch 44/150
# 33/33 [==============================] - 0s 2ms/step - loss: 3.6998e-04 - val_loss: 0.0076
# Epoch 45/150
# 33/33 [==============================] - 0s 2ms/step - loss: 3.6924e-04 - val_loss: 0.0074
# Epoch 46/150
# 33/33 [==============================] - 0s 2ms/step - loss: 3.5748e-04 - val_loss: 0.0075
# Epoch 47/150
# 33/33 [==============================] - 0s 2ms/step - loss: 3.4721e-04 - val_loss: 0.0071
# Epoch 48/150
# 33/33 [==============================] - 0s 2ms/step - loss: 3.3372e-04 - val_loss: 0.0079
# Epoch 49/150
# 33/33 [==============================] - 0s 2ms/step - loss: 3.5166e-04 - val_loss: 0.0071
# Epoch 50/150
# 33/33 [==============================] - 0s 2ms/step - loss: 3.5339e-04 - val_loss: 0.0071
# Epoch 51/150
# 33/33 [==============================] - 0s 2ms/step - loss: 3.3552e-04 - val_loss: 0.0066
# Epoch 52/150
# 33/33 [==============================] - 0s 2ms/step - loss: 3.2802e-04 - val_loss: 0.0067
# Epoch 53/150
# 33/33 [==============================] - 0s 2ms/step - loss: 3.1921e-04 - val_loss: 0.0059
# Epoch 54/150
# 33/33 [==============================] - 0s 2ms/step - loss: 3.1239e-04 - val_loss: 0.0065
# Epoch 55/150
# 33/33 [==============================] - 0s 2ms/step - loss: 3.0833e-04 - val_loss: 0.0065
# Epoch 56/150
# 33/33 [==============================] - 0s 2ms/step - loss: 3.0054e-04 - val_loss: 0.0070
# Epoch 57/150
# 33/33 [==============================] - 0s 2ms/step - loss: 2.9832e-04 - val_loss: 0.0062
# Epoch 58/150
# 33/33 [==============================] - 0s 2ms/step - loss: 2.9135e-04 - val_loss: 0.0062
# Epoch 59/150
# 33/33 [==============================] - 0s 2ms/step - loss: 3.0541e-04 - val_loss: 0.0065
# Epoch 60/150
# 33/33 [==============================] - 0s 2ms/step - loss: 2.8867e-04 - val_loss: 0.0068
# Epoch 61/150
# 33/33 [==============================] - 0s 2ms/step - loss: 2.8676e-04 - val_loss: 0.0064
# Epoch 62/150
# 33/33 [==============================] - 0s 2ms/step - loss: 2.8180e-04 - val_loss: 0.0060
# Epoch 63/150
# 33/33 [==============================] - 0s 2ms/step - loss: 2.8302e-04 - val_loss: 0.0061
# Epoch 64/150
# 33/33 [==============================] - 0s 2ms/step - loss: 2.8825e-04 - val_loss: 0.0059
# Epoch 65/150
# 33/33 [==============================] - 0s 2ms/step - loss: 2.8225e-04 - val_loss: 0.0062
# Epoch 66/150
# 33/33 [==============================] - 0s 2ms/step - loss: 2.7001e-04 - val_loss: 0.0059
# Epoch 67/150
# 33/33 [==============================] - 0s 2ms/step - loss: 2.7156e-04 - val_loss: 0.0063
# Epoch 68/150
# 33/33 [==============================] - 0s 2ms/step - loss: 2.6814e-04 - val_loss: 0.0059
# Epoch 69/150
# 33/33 [==============================] - 0s 2ms/step - loss: 2.5566e-04 - val_loss: 0.0056
# Epoch 70/150
# 33/33 [==============================] - 0s 2ms/step - loss: 2.5124e-04 - val_loss: 0.0062
# Epoch 71/150
# 33/33 [==============================] - 0s 2ms/step - loss: 2.5669e-04 - val_loss: 0.0060
# Epoch 72/150
# 33/33 [==============================] - 0s 2ms/step - loss: 2.5492e-04 - val_loss: 0.0059
# Epoch 73/150
# 33/33 [==============================] - 0s 2ms/step - loss: 2.5024e-04 - val_loss: 0.0057
# Epoch 74/150
# 33/33 [==============================] - 0s 2ms/step - loss: 2.6327e-04 - val_loss: 0.0056
# Epoch 75/150
# 33/33 [==============================] - 0s 2ms/step - loss: 2.7059e-04 - val_loss: 0.0060
# Epoch 76/150
# 33/33 [==============================] - 0s 2ms/step - loss: 2.5647e-04 - val_loss: 0.0058
# Epoch 77/150
# 33/33 [==============================] - 0s 2ms/step - loss: 2.7366e-04 - val_loss: 0.0056
# Epoch 78/150
# 33/33 [==============================] - 0s 2ms/step - loss: 2.5420e-04 - val_loss: 0.0055
# Epoch 79/150
# 33/33 [==============================] - 0s 2ms/step - loss: 2.3329e-04 - val_loss: 0.0050
# Epoch 80/150
# 33/33 [==============================] - 0s 2ms/step - loss: 2.2635e-04 - val_loss: 0.0055
# Epoch 81/150
# 33/33 [==============================] - 0s 2ms/step - loss: 2.6268e-04 - val_loss: 0.0054
# Epoch 82/150
# 33/33 [==============================] - 0s 2ms/step - loss: 2.2510e-04 - val_loss: 0.0051
# Epoch 83/150
# 33/33 [==============================] - 0s 2ms/step - loss: 2.2022e-04 - val_loss: 0.0051
# Epoch 84/150
# 33/33 [==============================] - 0s 2ms/step - loss: 2.2161e-04 - val_loss: 0.0053
# Epoch 85/150
# 33/33 [==============================] - 0s 2ms/step - loss: 2.1840e-04 - val_loss: 0.0051
# Epoch 86/150
# 33/33 [==============================] - 0s 2ms/step - loss: 2.0811e-04 - val_loss: 0.0053
# Epoch 87/150
# 33/33 [==============================] - 0s 2ms/step - loss: 2.0514e-04 - val_loss: 0.0054
# Epoch 88/150
# 33/33 [==============================] - 0s 2ms/step - loss: 2.1697e-04 - val_loss: 0.0051
# Epoch 89/150
# 33/33 [==============================] - 0s 2ms/step - loss: 2.2601e-04 - val_loss: 0.0052
# Epoch 90/150
# 33/33 [==============================] - 0s 2ms/step - loss: 2.1650e-04 - val_loss: 0.0053
# Epoch 91/150
# 33/33 [==============================] - 0s 2ms/step - loss: 2.1023e-04 - val_loss: 0.0054
# Epoch 92/150
# 33/33 [==============================] - 0s 2ms/step - loss: 2.1085e-04 - val_loss: 0.0049
# Epoch 93/150
# 33/33 [==============================] - 0s 2ms/step - loss: 1.9471e-04 - val_loss: 0.0049
# Epoch 94/150
# 33/33 [==============================] - 0s 2ms/step - loss: 1.9509e-04 - val_loss: 0.0050
# Epoch 95/150
# 33/33 [==============================] - 0s 2ms/step - loss: 2.0067e-04 - val_loss: 0.0052
# Epoch 96/150
# 33/33 [==============================] - 0s 2ms/step - loss: 1.9229e-04 - val_loss: 0.0051
# Epoch 97/150
# 33/33 [==============================] - 0s 2ms/step - loss: 2.0523e-04 - val_loss: 0.0053
# Epoch 98/150
# 33/33 [==============================] - 0s 2ms/step - loss: 1.9752e-04 - val_loss: 0.0050
# Epoch 99/150
# 33/33 [==============================] - 0s 3ms/step - loss: 2.0226e-04 - val_loss: 0.0054
# Epoch 100/150
# 33/33 [==============================] - 0s 3ms/step - loss: 1.9620e-04 - val_loss: 0.0052
# Epoch 101/150
# 33/33 [==============================] - 0s 2ms/step - loss: 1.8580e-04 - val_loss: 0.0052
# Epoch 102/150
# 33/33 [==============================] - 0s 2ms/step - loss: 1.7850e-04 - val_loss: 0.0049
# Epoch 103/150
# 33/33 [==============================] - 0s 2ms/step - loss: 1.9231e-04 - val_loss: 0.0052
# Epoch 104/150
# 33/33 [==============================] - 0s 2ms/step - loss: 1.8226e-04 - val_loss: 0.0050
# Epoch 105/150
# 33/33 [==============================] - 0s 2ms/step - loss: 1.7233e-04 - val_loss: 0.0049
# Epoch 106/150
# 33/33 [==============================] - 0s 3ms/step - loss: 1.8167e-04 - val_loss: 0.0047
# Epoch 107/150
# 33/33 [==============================] - 0s 2ms/step - loss: 1.7390e-04 - val_loss: 0.0051
# Epoch 108/150
# 33/33 [==============================] - 0s 2ms/step - loss: 1.6412e-04 - val_loss: 0.0053
# Epoch 109/150
# 33/33 [==============================] - 0s 2ms/step - loss: 1.7337e-04 - val_loss: 0.0051
# Epoch 110/150
# 33/33 [==============================] - 0s 2ms/step - loss: 1.8380e-04 - val_loss: 0.0050
# Epoch 111/150
# 33/33 [==============================] - 0s 2ms/step - loss: 1.8480e-04 - val_loss: 0.0050
# Epoch 112/150
# 33/33 [==============================] - 0s 2ms/step - loss: 1.7700e-04 - val_loss: 0.0053
# Epoch 113/150
# 33/33 [==============================] - 0s 2ms/step - loss: 1.7667e-04 - val_loss: 0.0053
# Epoch 114/150
# 33/33 [==============================] - 0s 2ms/step - loss: 1.7536e-04 - val_loss: 0.0053
# Epoch 115/150
# 33/33 [==============================] - 0s 2ms/step - loss: 1.7965e-04 - val_loss: 0.0051
# Epoch 116/150
# 33/33 [==============================] - 0s 2ms/step - loss: 1.7771e-04 - val_loss: 0.0051
# Epoch 117/150
# 33/33 [==============================] - 0s 2ms/step - loss: 1.6687e-04 - val_loss: 0.0050
# Epoch 118/150
# 33/33 [==============================] - 0s 2ms/step - loss: 1.5954e-04 - val_loss: 0.0048
# Epoch 119/150
# 33/33 [==============================] - 0s 2ms/step - loss: 1.5609e-04 - val_loss: 0.0053
# Epoch 120/150
# 33/33 [==============================] - 0s 2ms/step - loss: 1.6266e-04 - val_loss: 0.0047
# Epoch 121/150
# 33/33 [==============================] - 0s 2ms/step - loss: 1.5386e-04 - val_loss: 0.0049
# Epoch 122/150
# 33/33 [==============================] - 0s 2ms/step - loss: 1.5354e-04 - val_loss: 0.0053
# Epoch 123/150
# 33/33 [==============================] - 0s 2ms/step - loss: 1.4879e-04 - val_loss: 0.0053
# Epoch 124/150
# 33/33 [==============================] - 0s 2ms/step - loss: 1.4527e-04 - val_loss: 0.0049
# Epoch 125/150
# 33/33 [==============================] - 0s 2ms/step - loss: 1.4150e-04 - val_loss: 0.0052
# Epoch 126/150
# 33/33 [==============================] - 0s 2ms/step - loss: 1.4317e-04 - val_loss: 0.0052
# Epoch 127/150
# 33/33 [==============================] - 0s 2ms/step - loss: 1.5745e-04 - val_loss: 0.0054
# Epoch 128/150
# 33/33 [==============================] - 0s 2ms/step - loss: 1.6497e-04 - val_loss: 0.0055
# Epoch 129/150
# 33/33 [==============================] - 0s 2ms/step - loss: 1.5327e-04 - val_loss: 0.0048
# Epoch 130/150
# 33/33 [==============================] - 0s 2ms/step - loss: 1.5429e-04 - val_loss: 0.0049
# Epoch 131/150
# 33/33 [==============================] - 0s 2ms/step - loss: 1.3470e-04 - val_loss: 0.0053
# Epoch 132/150
# 33/33 [==============================] - 0s 2ms/step - loss: 1.4496e-04 - val_loss: 0.0051
# Epoch 133/150
# 33/33 [==============================] - 0s 2ms/step - loss: 1.4024e-04 - val_loss: 0.0053
# Epoch 134/150
# 33/33 [==============================] - 0s 2ms/step - loss: 1.4415e-04 - val_loss: 0.0051
# Epoch 135/150
# 33/33 [==============================] - 0s 2ms/step - loss: 1.4637e-04 - val_loss: 0.0050
# Epoch 136/150
# 33/33 [==============================] - 0s 2ms/step - loss: 1.3882e-04 - val_loss: 0.0050
# Epoch 137/150
# 33/33 [==============================] - 0s 2ms/step - loss: 1.3705e-04 - val_loss: 0.0049
# Epoch 138/150
# 33/33 [==============================] - 0s 2ms/step - loss: 1.3701e-04 - val_loss: 0.0051
# Epoch 139/150
# 33/33 [==============================] - 0s 2ms/step - loss: 1.3413e-04 - val_loss: 0.0050
# Epoch 140/150
# 33/33 [==============================] - 0s 3ms/step - loss: 1.3658e-04 - val_loss: 0.0046
# Epoch 141/150
# 33/33 [==============================] - 0s 2ms/step - loss: 1.2725e-04 - val_loss: 0.0051
# Epoch 142/150
# 33/33 [==============================] - 0s 2ms/step - loss: 1.2723e-04 - val_loss: 0.0050
# Epoch 143/150
# 33/33 [==============================] - 0s 2ms/step - loss: 1.3273e-04 - val_loss: 0.0049
# Epoch 144/150
# 33/33 [==============================] - 0s 2ms/step - loss: 1.3159e-04 - val_loss: 0.0051
# Epoch 145/150
# 33/33 [==============================] - 0s 2ms/step - loss: 1.2871e-04 - val_loss: 0.0051
# Epoch 146/150
# 33/33 [==============================] - 0s 2ms/step - loss: 1.2838e-04 - val_loss: 0.0049
# Epoch 147/150
# 33/33 [==============================] - 0s 2ms/step - loss: 1.2761e-04 - val_loss: 0.0048
# Epoch 148/150
# 33/33 [==============================] - 0s 2ms/step - loss: 1.1870e-04 - val_loss: 0.0049
# Epoch 149/150
# 33/33 [==============================] - 0s 2ms/step - loss: 1.1694e-04 - val_loss: 0.0047
# Epoch 150/150
# 33/33 [==============================] - 0s 2ms/step - loss: 1.1705e-04 - val_loss: 0.0049
# 42/42 [==============================] - 0s 974us/step

# %%
# Build the LSTM model
model = Sequential()
model.add(LSTM(50, return_sequences=True, input_shape=(sequence_length, len(include))))
model.add(LSTM(50, return_sequences=False))
model.add(Dense(25))
model.add(Dense(1))

model.compile(optimizer='adam', loss='mean_squared_error')
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm (LSTM)                 (None, 5, 50)             12200
#
#  lstm_1 (LSTM)               (None, 50)                20200
#
#  dense_6 (Dense)             (None, 25)                1275
#
#  dense_7 (Dense)             (None, 1)                 26
#
# =================================================================
# Total params: 33701 (131.64 KB)
# Trainable params: 33701 (131.64 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
model.fit(X_train, y_train, batch_size=64, epochs=150)
# Out:
# Epoch 1/150
# 21/21 [==============================] - 4s 5ms/step - loss: 0.0318
# Epoch 2/150
# 21/21 [==============================] - 0s 5ms/step - loss: 0.0058
# Epoch 3/150
# 21/21 [==============================] - 0s 6ms/step - loss: 0.0036
# Epoch 4/150
# 21/21 [==============================] - 0s 6ms/step - loss: 0.0020
# Epoch 5/150
# 21/21 [==============================] - 0s 5ms/step - loss: 0.0015
# Epoch 6/150
# 21/21 [==============================] - 0s 5ms/step - loss: 0.0013
# Epoch 7/150
# 21/21 [==============================] - 0s 5ms/step - loss: 0.0014
# Epoch 8/150
# 21/21 [==============================] - 0s 5ms/step - loss: 0.0013
# Epoch 9/150
# 21/21 [==============================] - 0s 5ms/step - loss: 0.0011
# Epoch 10/150
# 21/21 [==============================] - 0s 4ms/step - loss: 9.9004e-04
# Epoch 11/150
# 21/21 [==============================] - 0s 5ms/step - loss: 0.0011
# Epoch 12/150
# 21/21 [==============================] - 0s 5ms/step - loss: 9.5920e-04
# Epoch 13/150
# 21/21 [==============================] - 0s 5ms/step - loss: 9.2571e-04
# Epoch 14/150
# 21/21 [==============================] - 0s 5ms/step - loss: 9.2280e-04
# Epoch 15/150
# 21/21 [==============================] - 0s 5ms/step - loss: 8.9792e-04
# Epoch 16/150
# 21/21 [==============================] - 0s 5ms/step - loss: 9.0433e-04
# Epoch 17/150
# 21/21 [==============================] - 0s 4ms/step - loss: 8.8063e-04
# Epoch 18/150
# 21/21 [==============================] - 0s 4ms/step - loss: 8.1219e-04
# Epoch 19/150
# 21/21 [==============================] - 0s 4ms/step - loss: 9.5696e-04
# Epoch 20/150
# 21/21 [==============================] - 0s 4ms/step - loss: 0.0012
# Epoch 21/150
# 21/21 [==============================] - 0s 4ms/step - loss: 7.7196e-04
# Epoch 22/150
# 21/21 [==============================] - 0s 4ms/step - loss: 7.7993e-04
# Epoch 23/150
# 21/21 [==============================] - 0s 4ms/step - loss: 7.9772e-04
# Epoch 24/150
# 21/21 [==============================] - 0s 4ms/step - loss: 8.0969e-04
# Epoch 25/150
# 21/21 [==============================] - 0s 4ms/step - loss: 7.5847e-04
# Epoch 26/150
# 21/21 [==============================] - 0s 4ms/step - loss: 7.5410e-04
# Epoch 27/150
# 21/21 [==============================] - 0s 4ms/step - loss: 7.5644e-04
# Epoch 28/150
# 21/21 [==============================] - 0s 4ms/step - loss: 7.3251e-04
# Epoch 29/150
# 21/21 [==============================] - 0s 5ms/step - loss: 7.5708e-04
# Epoch 30/150
# 21/21 [==============================] - 0s 5ms/step - loss: 7.0213e-04
# Epoch 31/150
# 21/21 [==============================] - 0s 5ms/step - loss: 8.4831e-04
# Epoch 32/150
# 21/21 [==============================] - 0s 4ms/step - loss: 7.5391e-04
# Epoch 33/150
# 21/21 [==============================] - 0s 4ms/step - loss: 6.7035e-04
# Epoch 34/150
# 21/21 [==============================] - 0s 4ms/step - loss: 6.8313e-04
# Epoch 35/150
# 21/21 [==============================] - 0s 4ms/step - loss: 7.7828e-04
# Epoch 36/150
# 21/21 [==============================] - 0s 4ms/step - loss: 6.4884e-04
# Epoch 37/150
# 21/21 [==============================] - 0s 4ms/step - loss: 6.6913e-04
# Epoch 38/150
# 21/21 [==============================] - 0s 4ms/step - loss: 6.6726e-04
# Epoch 39/150
# 21/21 [==============================] - 0s 4ms/step - loss: 7.2722e-04
# Epoch 40/150
# 21/21 [==============================] - 0s 4ms/step - loss: 7.2292e-04
# Epoch 41/150
# 21/21 [==============================] - 0s 4ms/step - loss: 6.7445e-04
# Epoch 42/150
# 21/21 [==============================] - 0s 4ms/step - loss: 6.4129e-04
# Epoch 43/150
# 21/21 [==============================] - 0s 4ms/step - loss: 6.4217e-04
# Epoch 44/150
# 21/21 [==============================] - 0s 4ms/step - loss: 6.8308e-04
# Epoch 45/150
# 21/21 [==============================] - 0s 4ms/step - loss: 6.7119e-04
# Epoch 46/150
# 21/21 [==============================] - 0s 4ms/step - loss: 6.3725e-04
# Epoch 47/150
# 21/21 [==============================] - 0s 4ms/step - loss: 6.0876e-04
# Epoch 48/150
# 21/21 [==============================] - 0s 4ms/step - loss: 6.0990e-04
# Epoch 49/150
# 21/21 [==============================] - 0s 4ms/step - loss: 6.9340e-04
# Epoch 50/150
# 21/21 [==============================] - 0s 4ms/step - loss: 7.4158e-04
# Epoch 51/150
# 21/21 [==============================] - 0s 3ms/step - loss: 6.0120e-04
# Epoch 52/150
# 21/21 [==============================] - 0s 4ms/step - loss: 6.4288e-04
# Epoch 53/150
# 21/21 [==============================] - 0s 4ms/step - loss: 6.0195e-04
# Epoch 54/150
# 21/21 [==============================] - 0s 4ms/step - loss: 6.1642e-04
# Epoch 55/150
# 21/21 [==============================] - 0s 4ms/step - loss: 6.0012e-04
# Epoch 56/150
# 21/21 [==============================] - 0s 4ms/step - loss: 6.7876e-04
# Epoch 57/150
# 21/21 [==============================] - 0s 4ms/step - loss: 5.9276e-04
# Epoch 58/150
# 21/21 [==============================] - 0s 4ms/step - loss: 6.5774e-04
# Epoch 59/150
# 21/21 [==============================] - 0s 4ms/step - loss: 6.1406e-04
# Epoch 60/150
# 21/21 [==============================] - 0s 4ms/step - loss: 5.7662e-04
# Epoch 61/150
# 21/21 [==============================] - 0s 4ms/step - loss: 6.2605e-04
# Epoch 62/150
# 21/21 [==============================] - 0s 4ms/step - loss: 6.8054e-04
# Epoch 63/150
# 21/21 [==============================] - 0s 4ms/step - loss: 5.5008e-04
# Epoch 64/150
# 21/21 [==============================] - 0s 4ms/step - loss: 5.9970e-04
# Epoch 65/150
# 21/21 [==============================] - 0s 4ms/step - loss: 5.4962e-04
# Epoch 66/150
# 21/21 [==============================] - 0s 4ms/step - loss: 5.6363e-04
# Epoch 67/150
# 21/21 [==============================] - 0s 4ms/step - loss: 5.8423e-04
# Epoch 68/150
# 21/21 [==============================] - 0s 4ms/step - loss: 5.8759e-04
# Epoch 69/150
# 21/21 [==============================] - 0s 4ms/step - loss: 8.5740e-04
# Epoch 70/150
# 21/21 [==============================] - 0s 4ms/step - loss: 6.3873e-04
# Epoch 71/150
# 21/21 [==============================] - 0s 3ms/step - loss: 7.4055e-04
# Epoch 72/150
# 21/21 [==============================] - 0s 3ms/step - loss: 6.6369e-04
# Epoch 73/150
# 21/21 [==============================] - 0s 4ms/step - loss: 5.7851e-04
# Epoch 74/150
# 21/21 [==============================] - 0s 3ms/step - loss: 5.4115e-04
# Epoch 75/150
# 21/21 [==============================] - 0s 4ms/step - loss: 5.3721e-04
# Epoch 76/150
# 21/21 [==============================] - 0s 4ms/step - loss: 5.4639e-04
# Epoch 77/150
# 21/21 [==============================] - 0s 4ms/step - loss: 5.3195e-04
# Epoch 78/150
# 21/21 [==============================] - 0s 5ms/step - loss: 6.5142e-04
# Epoch 79/150
# 21/21 [==============================] - 0s 4ms/step - loss: 5.1189e-04
# Epoch 80/150
# 21/21 [==============================] - 0s 5ms/step - loss: 5.3759e-04
# Epoch 81/150
# 21/21 [==============================] - 0s 4ms/step - loss: 4.8859e-04
# Epoch 82/150
# 21/21 [==============================] - 0s 4ms/step - loss: 5.2637e-04
# Epoch 83/150
# 21/21 [==============================] - 0s 5ms/step - loss: 5.2590e-04
# Epoch 84/150
# 21/21 [==============================] - 0s 5ms/step - loss: 4.6460e-04
# Epoch 85/150
# 21/21 [==============================] - 0s 5ms/step - loss: 4.4907e-04
# Epoch 86/150
# 21/21 [==============================] - 0s 4ms/step - loss: 4.6648e-04
# Epoch 87/150
# 21/21 [==============================] - 0s 4ms/step - loss: 6.4935e-04
# Epoch 88/150
# 21/21 [==============================] - 0s 4ms/step - loss: 6.2857e-04
# Epoch 89/150
# 21/21 [==============================] - 0s 4ms/step - loss: 5.1180e-04
# Epoch 90/150
# 21/21 [==============================] - 0s 4ms/step - loss: 5.6232e-04
# Epoch 91/150
# 21/21 [==============================] - 0s 4ms/step - loss: 6.5496e-04
# Epoch 92/150
# 21/21 [==============================] - 0s 4ms/step - loss: 5.6413e-04
# Epoch 93/150
# 21/21 [==============================] - 0s 4ms/step - loss: 4.6071e-04
# Epoch 94/150
# 21/21 [==============================] - 0s 4ms/step - loss: 4.3639e-04
# Epoch 95/150
# 21/21 [==============================] - 0s 3ms/step - loss: 4.3304e-04
# Epoch 96/150
# 21/21 [==============================] - 0s 4ms/step - loss: 5.0561e-04
# Epoch 97/150
# 21/21 [==============================] - 0s 4ms/step - loss: 4.6301e-04
# Epoch 98/150
# 21/21 [==============================] - 0s 4ms/step - loss: 4.3911e-04
# Epoch 99/150
# 21/21 [==============================] - 0s 4ms/step - loss: 4.6694e-04
# Epoch 100/150
# 21/21 [==============================] - 0s 4ms/step - loss: 4.9302e-04
# Epoch 101/150
# 21/21 [==============================] - 0s 5ms/step - loss: 5.5286e-04
# Epoch 102/150
# 21/21 [==============================] - 0s 5ms/step - loss: 4.8297e-04
# Epoch 103/150
# 21/21 [==============================] - 0s 6ms/step - loss: 4.3209e-04
# Epoch 104/150
# 21/21 [==============================] - 0s 5ms/step - loss: 4.5172e-04
# Epoch 105/150
# 21/21 [==============================] - 0s 4ms/step - loss: 5.3857e-04
# Epoch 106/150
# 21/21 [==============================] - 0s 4ms/step - loss: 4.5411e-04
# Epoch 107/150
# 21/21 [==============================] - 0s 5ms/step - loss: 5.0204e-04
# Epoch 108/150
# 21/21 [==============================] - 0s 5ms/step - loss: 4.6895e-04
# Epoch 109/150
# 21/21 [==============================] - 0s 5ms/step - loss: 4.3956e-04
# Epoch 110/150
# 21/21 [==============================] - 0s 4ms/step - loss: 4.3556e-04
# Epoch 111/150
# 21/21 [==============================] - 0s 4ms/step - loss: 4.3183e-04
# Epoch 112/150
# 21/21 [==============================] - 0s 4ms/step - loss: 4.3034e-04
# Epoch 113/150
# 21/21 [==============================] - 0s 5ms/step - loss: 5.6904e-04
# Epoch 114/150
# 21/21 [==============================] - 0s 6ms/step - loss: 4.1765e-04
# Epoch 115/150
# 21/21 [==============================] - 0s 5ms/step - loss: 5.1173e-04
# Epoch 116/150
# 21/21 [==============================] - 0s 5ms/step - loss: 4.6158e-04
# Epoch 117/150
# 21/21 [==============================] - 0s 5ms/step - loss: 4.2728e-04
# Epoch 118/150
# 21/21 [==============================] - 0s 5ms/step - loss: 4.6311e-04
# Epoch 119/150
# 21/21 [==============================] - 0s 5ms/step - loss: 4.0399e-04
# Epoch 120/150
# 21/21 [==============================] - 0s 4ms/step - loss: 3.7761e-04
# Epoch 121/150
# 21/21 [==============================] - 0s 5ms/step - loss: 4.9875e-04
# Epoch 122/150
# 21/21 [==============================] - 0s 6ms/step - loss: 4.3691e-04
# Epoch 123/150
# 21/21 [==============================] - 0s 6ms/step - loss: 3.9492e-04
# Epoch 124/150
# 21/21 [==============================] - 0s 6ms/step - loss: 4.0183e-04
# Epoch 125/150
# 21/21 [==============================] - 0s 5ms/step - loss: 3.8109e-04
# Epoch 126/150
# 21/21 [==============================] - 0s 4ms/step - loss: 4.0631e-04
# Epoch 127/150
# 21/21 [==============================] - 0s 5ms/step - loss: 4.3330e-04
# Epoch 128/150
# 21/21 [==============================] - 0s 6ms/step - loss: 3.6749e-04
# Epoch 129/150
# 21/21 [==============================] - 0s 5ms/step - loss: 4.1788e-04
# Epoch 130/150
# 21/21 [==============================] - 0s 4ms/step - loss: 4.2104e-04
# Epoch 131/150
# 21/21 [==============================] - 0s 4ms/step - loss: 3.9322e-04
# Epoch 132/150
# 21/21 [==============================] - 0s 4ms/step - loss: 3.8084e-04
# Epoch 133/150
# 21/21 [==============================] - 0s 5ms/step - loss: 4.1015e-04
# Epoch 134/150
# 21/21 [==============================] - 0s 5ms/step - loss: 3.8994e-04
# Epoch 135/150
# 21/21 [==============================] - 0s 4ms/step - loss: 4.0082e-04
# Epoch 136/150
# 21/21 [==============================] - 0s 6ms/step - loss: 4.2215e-04
# Epoch 137/150
# 21/21 [==============================] - 0s 6ms/step - loss: 3.7283e-04
# Epoch 138/150
# 21/21 [==============================] - 0s 5ms/step - loss: 3.6920e-04
# Epoch 139/150
# 21/21 [==============================] - 0s 4ms/step - loss: 3.8140e-04
# Epoch 140/150
# 21/21 [==============================] - 0s 4ms/step - loss: 3.7957e-04
# Epoch 141/150
# 21/21 [==============================] - 0s 4ms/step - loss: 3.8690e-04
# Epoch 142/150
# 21/21 [==============================] - 0s 4ms/step - loss: 3.6881e-04
# Epoch 143/150
# 21/21 [==============================] - 0s 4ms/step - loss: 4.3634e-04
# Epoch 144/150
# 21/21 [==============================] - 0s 4ms/step - loss: 3.9899e-04
# Epoch 145/150
# 21/21 [==============================] - 0s 4ms/step - loss: 4.4690e-04
# Epoch 146/150
# 21/21 [==============================] - 0s 4ms/step - loss: 3.7578e-04
# Epoch 147/150
# 21/21 [==============================] - 0s 4ms/step - loss: 4.5972e-04
# Epoch 148/150
# 21/21 [==============================] - 0s 4ms/step - loss: 5.4697e-04
# Epoch 149/150
# 21/21 [==============================] - 0s 4ms/step - loss: 3.9445e-04
# Epoch 150/150
# 21/21 [==============================] - 0s 4ms/step - loss: 5.0126e-04

# %%
# Predict values
predictions = model.predict(X_test)
predictions = scaler.inverse_transform(np.concatenate((predictions, np.zeros((predictions.shape[0], len(include)-1))), axis=1))[:, 0]

# Slice the actual prices to align with the predictions
actual_prices_aligned = df.loc[start_date_testing:end_date_testing, CLOSE][-len(predictions):]
predictions = pd.DataFrame(predictions, index=actual_prices_aligned.index, columns=['Predicted_Close'])

# Convert actual_prices_aligned to a DataFrame
actual_prices_aligned_df = pd.DataFrame(actual_prices_aligned, columns=[CLOSE])

# Calculating the logarithm of predictions and then the logarithmic difference
actual_prices_aligned_df['Predicted_Close'] = predictions
actual_prices_aligned_df['Predicted_Close'] = np.log(actual_prices_aligned_df['Predicted_Close'])
log_diff_predicted = actual_prices_aligned_df['Predicted_Close'].diff().fillna(0)
log_diff_actual = pd.DataFrame(df["Log_Diff_Close"], index=actual_prices_aligned.index, columns=['Log_Diff_Close'])
# Out:
# 5/5 [==============================] - 1s 2ms/step

# %%
# Calculate RMSE
rmse = math.sqrt(mean_squared_error(actual_prices_aligned, predictions))
print('Root Mean Squared Error (RMSE):', rmse)

# Calculate MAE
mae = mean_absolute_error(actual_prices_aligned, predictions)
print('Mean Absolute Error (MAE):', mae)

# Calculate RMSE Log diff
rmse = math.sqrt(mean_squared_error(log_diff_actual, log_diff_predicted))
print('Root Mean Squared Error (RMSE):', rmse)

# Calculate MAE Log diff
mae = mean_absolute_error(log_diff_actual, log_diff_predicted)
print('Mean Absolute Error (MAE):', mae)
# Out:
# Root Mean Squared Error (RMSE): 17049.565431917843
# Mean Absolute Error (MAE): 16857.02722601892

# %%
# Existing plot for 'Close' prices
plt.figure(figsize=(16, 8))
plt.subplot(2, 1, 1)  # First subplot in a 2x1 grid
plt.plot(actual_prices_aligned, label='Actual Close Price', color='blue')
plt.plot(predictions, label='Predicted Close Price', color='red')
plt.title('Bitcoin Price and Logarithmic Difference')
plt.ylabel('BTC Price')
plt.legend()

# New plot for 'Log_Diff_Close'
plt.subplot(2, 1, 2)  # Second subplot in a 2x1 grid
plt.plot(log_diff_actual, label='Logarithmic Difference of Close', color='green')
plt.plot(log_diff_predicted, label='Predicted Logarithmic Difference of Close', color='orange')
plt.xlabel('Time')
plt.ylabel('Log Difference')
plt.legend()

plt.show()
