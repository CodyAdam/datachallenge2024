# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import MinMaxScaler
from tensorflow.keras.models import Sequential, Model
from tensorflow.keras.layers import LSTM, Dense, Input
import matplotlib.pyplot as plt
import tensorflow as tf
import random

import os 
from sklearn.metrics import mean_squared_error, mean_absolute_error
import math
# Out:
# 2024-01-20 14:10:27.303578: I external/local_tsl/tsl/cuda/cudart_stub.cc:31] Could not find cuda drivers on your machine, GPU will not be used.
# 2024-01-20 14:10:27.333182: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-01-20 14:10:27.333202: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-01-20 14:10:27.333947: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-01-20 14:10:27.337963: I external/local_tsl/tsl/cuda/cudart_stub.cc:31] Could not find cuda drivers on your machine, GPU will not be used.
# 2024-01-20 14:10:27.338513: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2024-01-20 14:10:27.994127: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT

# %%
CURRENCY = "BTC"
CLOSE = f"Close_{CURRENCY}"

seed = random.randint(0, 1000000)
seed = 122751
print(seed)
tf.random.set_seed(seed)
np.random.seed(seed)
random.seed(seed)
# Out:
# 122751

# %%
dataset_pickle = '../../data/federalfinancegestion/dataset.pkl'
df = pd.read_pickle(dataset_pickle)

# Remove all string (object type) columns from the dataset
data_numeric = df.select_dtypes(exclude=['object'])

# Finding the column that closely matches "Close_BTC" in the numeric dataset
close_btc_column_numeric = [col for col in data_numeric.columns if "Close_BTC" in col]

close_btc_column_numeric = close_btc_column_numeric[0]
# Calculate the correlation of all columns with Close_BTC in the numeric dataset
correlation_with_close_btc_numeric = data_numeric.corr()[close_btc_column_numeric].sort_values(ascending=False)

# Extract the top 10 most correlated feature names
top_feature = correlation_with_close_btc_numeric.head(10).index.tolist()
include = top_feature

# %%
# Load data
df.fillna(0, inplace=True)
df['date'] = pd.to_datetime(df['date'])
df.set_index('date', inplace=True)

start_date_training = pd.to_datetime('2017-08-01')
end_date_training = pd.to_datetime('2022-08-31')
start_date_testing = pd.to_datetime('2022-09-01')
end_date_testing = pd.to_datetime('2023-04-30')

# %%
train_df = df.loc[start_date_training:end_date_training]
test_df = df.loc[start_date_testing:end_date_testing]

# %%
# Calculating the logarithmic difference of 'Close'
df['Close_Log'] = np.log(df[CLOSE])  # First, compute the log of 'Close'
df['Log_Diff_Close'] = df['Close_Log'].diff().fillna(0)  # Then compute the difference and handle NaN

# %%
# Include features
train = train_df[include].values
test = test_df[include].values

# %%
# Normalize the data
scaler = MinMaxScaler(feature_range=(0, 1))
train_scaled = scaler.fit_transform(train)
test_scaled = scaler.transform(test)

# %%
# # # SDAE
input_layer = Input(shape=(len(include),))
encoded = Dense(64, activation='relu')(input_layer)
encoded = Dense(32, activation='relu')(encoded)
encoded = Dense(16, activation='relu')(encoded)

decoded = Dense(32, activation='relu')(encoded)
decoded = Dense(64, activation='relu')(decoded)
decoded = Dense(len(include), activation='sigmoid')(decoded)

autoencoder = Model(input_layer, decoded)
autoencoder.compile(optimizer='adam', loss='mse')

# Train the autoencoder
autoencoder.fit(train_scaled, train_scaled, epochs=150, batch_size=32, shuffle=True, validation_split=0.2)

# Get the encoded representation of the data
encoded_features = autoencoder.predict(train_scaled)

def create_sequences(data, sequence_length):
    xs, ys = [], []
    for i in range(len(data) - sequence_length):
        x = data[i:(i + sequence_length), :]
        y = data[i + sequence_length, 0]
        xs.append(x)
        ys.append(y)
    return np.array(xs), np.array(ys)

sequence_length = 5  # Number of days used to predict the next day
X_train, y_train = create_sequences(train_scaled, sequence_length)
X_test, y_test = create_sequences(test_scaled, sequence_length)

# Reshape inputs for LSTM [samples, time steps, features]
X_train = np.reshape(X_train, (X_train.shape[0], X_train.shape[1], len(include)))
X_test = np.reshape(X_test, (X_test.shape[0], X_test.shape[1], len(include)))
# Out:
# WARNING:tensorflow:From c:\Users\codya\AppData\Local\Programs\Python\Python311\Lib\site-packages\keras\src\backend.py:1398: The name tf.executing_eagerly_outside_functions is deprecated. Please use tf.compat.v1.executing_eagerly_outside_functions instead.
#
# WARNING:tensorflow:From c:\Users\codya\AppData\Local\Programs\Python\Python311\Lib\site-packages\keras\src\optimizers\__init__.py:309: The name tf.train.Optimizer is deprecated. Please use tf.compat.v1.train.Optimizer instead.
#
# Epoch 1/150
# WARNING:tensorflow:From c:\Users\codya\AppData\Local\Programs\Python\Python311\Lib\site-packages\keras\src\utils\tf_utils.py:492: The name tf.ragged.RaggedTensorValue is deprecated. Please use tf.compat.v1.ragged.RaggedTensorValue instead.
#
# 33/33 [==============================] - 1s 5ms/step - loss: 0.1212 - val_loss: 0.0905
# Epoch 2/150
# 33/33 [==============================] - 0s 2ms/step - loss: 0.0340 - val_loss: 0.0543
# Epoch 3/150
# 33/33 [==============================] - 0s 2ms/step - loss: 0.0104 - val_loss: 0.0210
# Epoch 4/150
# 33/33 [==============================] - 0s 2ms/step - loss: 0.0070 - val_loss: 0.0159
# Epoch 5/150
# 33/33 [==============================] - 0s 2ms/step - loss: 0.0052 - val_loss: 0.0147
# Epoch 6/150
# 33/33 [==============================] - 0s 2ms/step - loss: 0.0041 - val_loss: 0.0142
# Epoch 7/150
# 33/33 [==============================] - 0s 2ms/step - loss: 0.0036 - val_loss: 0.0136
# Epoch 8/150
# 33/33 [==============================] - 0s 2ms/step - loss: 0.0032 - val_loss: 0.0141
# Epoch 9/150
# 33/33 [==============================] - 0s 2ms/step - loss: 0.0028 - val_loss: 0.0137
# Epoch 10/150
# 33/33 [==============================] - 0s 2ms/step - loss: 0.0024 - val_loss: 0.0132
# Epoch 11/150
# 33/33 [==============================] - 0s 2ms/step - loss: 0.0021 - val_loss: 0.0130
# Epoch 12/150
# 33/33 [==============================] - 0s 2ms/step - loss: 0.0019 - val_loss: 0.0130
# Epoch 13/150
# 33/33 [==============================] - 0s 2ms/step - loss: 0.0016 - val_loss: 0.0126
# Epoch 14/150
# 33/33 [==============================] - 0s 2ms/step - loss: 0.0014 - val_loss: 0.0119
# Epoch 15/150
# 33/33 [==============================] - 0s 2ms/step - loss: 0.0013 - val_loss: 0.0119
# Epoch 16/150
# 33/33 [==============================] - 0s 2ms/step - loss: 0.0012 - val_loss: 0.0123
# Epoch 17/150
# 33/33 [==============================] - 0s 2ms/step - loss: 0.0012 - val_loss: 0.0110
# Epoch 18/150
# 33/33 [==============================] - 0s 2ms/step - loss: 0.0011 - val_loss: 0.0111
# Epoch 19/150
# 33/33 [==============================] - 0s 2ms/step - loss: 0.0010 - val_loss: 0.0108
# Epoch 20/150
# 33/33 [==============================] - 0s 2ms/step - loss: 0.0010 - val_loss: 0.0120
# Epoch 21/150
# 33/33 [==============================] - 0s 2ms/step - loss: 9.6626e-04 - val_loss: 0.0109
# Epoch 22/150
# 33/33 [==============================] - 0s 2ms/step - loss: 9.2171e-04 - val_loss: 0.0111
# Epoch 23/150
# 33/33 [==============================] - 0s 2ms/step - loss: 8.9170e-04 - val_loss: 0.0111
# Epoch 24/150
# 33/33 [==============================] - 0s 2ms/step - loss: 8.7175e-04 - val_loss: 0.0108
# Epoch 25/150
# 33/33 [==============================] - 0s 2ms/step - loss: 8.3316e-04 - val_loss: 0.0106
# Epoch 26/150
# 33/33 [==============================] - 0s 2ms/step - loss: 8.0496e-04 - val_loss: 0.0107
# Epoch 27/150
# 33/33 [==============================] - 0s 2ms/step - loss: 8.2679e-04 - val_loss: 0.0100
# Epoch 28/150
# 33/33 [==============================] - 0s 2ms/step - loss: 7.7687e-04 - val_loss: 0.0106
# Epoch 29/150
# 33/33 [==============================] - 0s 2ms/step - loss: 7.1998e-04 - val_loss: 0.0103
# Epoch 30/150
# 33/33 [==============================] - 0s 2ms/step - loss: 6.9785e-04 - val_loss: 0.0100
# Epoch 31/150
# 33/33 [==============================] - 0s 2ms/step - loss: 6.6623e-04 - val_loss: 0.0101
# Epoch 32/150
# 33/33 [==============================] - 0s 2ms/step - loss: 6.5533e-04 - val_loss: 0.0105
# Epoch 33/150
# 33/33 [==============================] - 0s 2ms/step - loss: 6.2327e-04 - val_loss: 0.0097
# Epoch 34/150
# 33/33 [==============================] - 0s 2ms/step - loss: 5.8680e-04 - val_loss: 0.0093
# Epoch 35/150
# 33/33 [==============================] - 0s 2ms/step - loss: 5.2970e-04 - val_loss: 0.0095
# Epoch 36/150
# 33/33 [==============================] - 0s 2ms/step - loss: 5.4922e-04 - val_loss: 0.0106
# Epoch 37/150
# 33/33 [==============================] - 0s 2ms/step - loss: 5.2399e-04 - val_loss: 0.0104
# Epoch 38/150
# 33/33 [==============================] - 0s 2ms/step - loss: 5.2305e-04 - val_loss: 0.0089
# Epoch 39/150
# 33/33 [==============================] - 0s 2ms/step - loss: 5.0387e-04 - val_loss: 0.0098
# Epoch 40/150
# 33/33 [==============================] - 0s 2ms/step - loss: 4.6629e-04 - val_loss: 0.0093
# Epoch 41/150
# 33/33 [==============================] - 0s 2ms/step - loss: 4.5097e-04 - val_loss: 0.0084
# Epoch 42/150
# 33/33 [==============================] - 0s 2ms/step - loss: 4.5033e-04 - val_loss: 0.0098
# Epoch 43/150
# 33/33 [==============================] - 0s 2ms/step - loss: 4.4257e-04 - val_loss: 0.0094
# Epoch 44/150
# 33/33 [==============================] - 0s 2ms/step - loss: 4.1344e-04 - val_loss: 0.0088
# Epoch 45/150
# 33/33 [==============================] - 0s 2ms/step - loss: 4.1689e-04 - val_loss: 0.0088
# Epoch 46/150
# 33/33 [==============================] - 0s 2ms/step - loss: 4.0971e-04 - val_loss: 0.0088
# Epoch 47/150
# 33/33 [==============================] - 0s 2ms/step - loss: 4.0873e-04 - val_loss: 0.0090
# Epoch 48/150
# 33/33 [==============================] - 0s 2ms/step - loss: 3.8670e-04 - val_loss: 0.0087
# Epoch 49/150
# 33/33 [==============================] - 0s 2ms/step - loss: 3.7869e-04 - val_loss: 0.0091
# Epoch 50/150
# 33/33 [==============================] - 0s 2ms/step - loss: 3.7295e-04 - val_loss: 0.0089
# Epoch 51/150
# 33/33 [==============================] - 0s 2ms/step - loss: 3.6922e-04 - val_loss: 0.0084
# Epoch 52/150
# 33/33 [==============================] - 0s 2ms/step - loss: 3.6101e-04 - val_loss: 0.0100
# Epoch 53/150
# 33/33 [==============================] - 0s 2ms/step - loss: 3.5010e-04 - val_loss: 0.0088
# Epoch 54/150
# 33/33 [==============================] - 0s 2ms/step - loss: 3.4953e-04 - val_loss: 0.0089
# Epoch 55/150
# 33/33 [==============================] - 0s 2ms/step - loss: 3.3974e-04 - val_loss: 0.0088
# Epoch 56/150
# 33/33 [==============================] - 0s 2ms/step - loss: 3.3587e-04 - val_loss: 0.0088
# Epoch 57/150
# 33/33 [==============================] - 0s 2ms/step - loss: 3.2293e-04 - val_loss: 0.0077
# Epoch 58/150
# 33/33 [==============================] - 0s 2ms/step - loss: 3.2059e-04 - val_loss: 0.0085
# Epoch 59/150
# 33/33 [==============================] - 0s 2ms/step - loss: 3.2277e-04 - val_loss: 0.0085
# Epoch 60/150
# 33/33 [==============================] - 0s 2ms/step - loss: 3.2315e-04 - val_loss: 0.0087
# Epoch 61/150
# 33/33 [==============================] - 0s 2ms/step - loss: 3.2866e-04 - val_loss: 0.0091
# Epoch 62/150
# 33/33 [==============================] - 0s 2ms/step - loss: 3.0541e-04 - val_loss: 0.0084
# Epoch 63/150
# 33/33 [==============================] - 0s 2ms/step - loss: 3.0113e-04 - val_loss: 0.0089
# Epoch 64/150
# 33/33 [==============================] - 0s 2ms/step - loss: 3.0547e-04 - val_loss: 0.0089
# Epoch 65/150
# 33/33 [==============================] - 0s 2ms/step - loss: 2.9402e-04 - val_loss: 0.0089
# Epoch 66/150
# 33/33 [==============================] - 0s 2ms/step - loss: 2.9846e-04 - val_loss: 0.0093
# Epoch 67/150
# 33/33 [==============================] - 0s 2ms/step - loss: 2.9374e-04 - val_loss: 0.0086
# Epoch 68/150
# 33/33 [==============================] - 0s 2ms/step - loss: 2.8522e-04 - val_loss: 0.0090
# Epoch 69/150
# 33/33 [==============================] - 0s 2ms/step - loss: 2.8079e-04 - val_loss: 0.0083
# Epoch 70/150
# 33/33 [==============================] - 0s 2ms/step - loss: 2.9183e-04 - val_loss: 0.0088
# Epoch 71/150
# 33/33 [==============================] - 0s 2ms/step - loss: 2.5879e-04 - val_loss: 0.0085
# Epoch 72/150
# 33/33 [==============================] - 0s 2ms/step - loss: 2.6112e-04 - val_loss: 0.0088
# Epoch 73/150
# 33/33 [==============================] - 0s 2ms/step - loss: 2.6755e-04 - val_loss: 0.0083
# Epoch 74/150
# 33/33 [==============================] - 0s 2ms/step - loss: 2.6224e-04 - val_loss: 0.0087
# Epoch 75/150
# 33/33 [==============================] - 0s 2ms/step - loss: 2.6480e-04 - val_loss: 0.0093
# Epoch 76/150
# 33/33 [==============================] - 0s 2ms/step - loss: 2.5939e-04 - val_loss: 0.0080
# Epoch 77/150
# 33/33 [==============================] - 0s 2ms/step - loss: 2.5012e-04 - val_loss: 0.0075
# Epoch 78/150
# 33/33 [==============================] - 0s 2ms/step - loss: 2.5514e-04 - val_loss: 0.0091
# Epoch 79/150
# 33/33 [==============================] - 0s 2ms/step - loss: 2.5084e-04 - val_loss: 0.0086
# Epoch 80/150
# 33/33 [==============================] - 0s 2ms/step - loss: 2.3803e-04 - val_loss: 0.0086
# Epoch 81/150
# 33/33 [==============================] - 0s 2ms/step - loss: 2.4452e-04 - val_loss: 0.0085
# Epoch 82/150
# 33/33 [==============================] - 0s 2ms/step - loss: 2.3858e-04 - val_loss: 0.0080
# Epoch 83/150
# 33/33 [==============================] - 0s 2ms/step - loss: 2.4516e-04 - val_loss: 0.0094
# Epoch 84/150
# 33/33 [==============================] - 0s 2ms/step - loss: 2.4396e-04 - val_loss: 0.0086
# Epoch 85/150
# 33/33 [==============================] - 0s 2ms/step - loss: 2.4161e-04 - val_loss: 0.0092
# Epoch 86/150
# 33/33 [==============================] - 0s 2ms/step - loss: 2.2919e-04 - val_loss: 0.0078
# Epoch 87/150
# 33/33 [==============================] - 0s 2ms/step - loss: 2.2609e-04 - val_loss: 0.0085
# Epoch 88/150
# 33/33 [==============================] - 0s 2ms/step - loss: 2.3872e-04 - val_loss: 0.0084
# Epoch 89/150
# 33/33 [==============================] - 0s 2ms/step - loss: 2.4843e-04 - val_loss: 0.0090
# Epoch 90/150
# 33/33 [==============================] - 0s 2ms/step - loss: 2.3802e-04 - val_loss: 0.0079
# Epoch 91/150
# 33/33 [==============================] - 0s 2ms/step - loss: 2.1573e-04 - val_loss: 0.0071
# Epoch 92/150
# 33/33 [==============================] - 0s 2ms/step - loss: 2.3465e-04 - val_loss: 0.0086
# Epoch 93/150
# 33/33 [==============================] - 0s 2ms/step - loss: 2.4743e-04 - val_loss: 0.0080
# Epoch 94/150
# 33/33 [==============================] - 0s 2ms/step - loss: 2.4767e-04 - val_loss: 0.0085
# Epoch 95/150
# 33/33 [==============================] - 0s 2ms/step - loss: 2.4749e-04 - val_loss: 0.0086
# Epoch 96/150
# 33/33 [==============================] - 0s 2ms/step - loss: 2.3668e-04 - val_loss: 0.0086
# Epoch 97/150
# 33/33 [==============================] - 0s 2ms/step - loss: 2.2372e-04 - val_loss: 0.0093
# Epoch 98/150
# 33/33 [==============================] - 0s 2ms/step - loss: 2.2732e-04 - val_loss: 0.0079
# Epoch 99/150
# 33/33 [==============================] - 0s 2ms/step - loss: 2.6620e-04 - val_loss: 0.0085
# Epoch 100/150
# 33/33 [==============================] - 0s 2ms/step - loss: 2.2989e-04 - val_loss: 0.0089
# Epoch 101/150
# 33/33 [==============================] - 0s 2ms/step - loss: 2.1830e-04 - val_loss: 0.0087
# Epoch 102/150
# 33/33 [==============================] - 0s 2ms/step - loss: 1.9563e-04 - val_loss: 0.0086
# Epoch 103/150
# 33/33 [==============================] - 0s 2ms/step - loss: 1.9869e-04 - val_loss: 0.0083
# Epoch 104/150
# 33/33 [==============================] - 0s 2ms/step - loss: 2.1100e-04 - val_loss: 0.0090
# Epoch 105/150
# 33/33 [==============================] - 0s 2ms/step - loss: 2.1281e-04 - val_loss: 0.0086
# Epoch 106/150
# 33/33 [==============================] - 0s 2ms/step - loss: 2.0142e-04 - val_loss: 0.0088
# Epoch 107/150
# 33/33 [==============================] - 0s 2ms/step - loss: 2.1127e-04 - val_loss: 0.0086
# Epoch 108/150
# 33/33 [==============================] - 0s 2ms/step - loss: 1.9421e-04 - val_loss: 0.0083
# Epoch 109/150
# 33/33 [==============================] - 0s 2ms/step - loss: 1.9307e-04 - val_loss: 0.0082
# Epoch 110/150
# 33/33 [==============================] - 0s 2ms/step - loss: 1.8547e-04 - val_loss: 0.0079
# Epoch 111/150
# 33/33 [==============================] - 0s 2ms/step - loss: 1.9471e-04 - val_loss: 0.0087
# Epoch 112/150
# 33/33 [==============================] - 0s 2ms/step - loss: 1.9300e-04 - val_loss: 0.0087
# Epoch 113/150
# 33/33 [==============================] - 0s 2ms/step - loss: 1.9440e-04 - val_loss: 0.0089
# Epoch 114/150
# 33/33 [==============================] - 0s 2ms/step - loss: 1.9313e-04 - val_loss: 0.0090
# Epoch 115/150
# 33/33 [==============================] - 0s 2ms/step - loss: 1.9066e-04 - val_loss: 0.0083
# Epoch 116/150
# 33/33 [==============================] - 0s 2ms/step - loss: 1.8638e-04 - val_loss: 0.0083
# Epoch 117/150
# 33/33 [==============================] - 0s 2ms/step - loss: 1.9099e-04 - val_loss: 0.0092
# Epoch 118/150
# 33/33 [==============================] - 0s 2ms/step - loss: 1.9186e-04 - val_loss: 0.0087
# Epoch 119/150
# 33/33 [==============================] - 0s 2ms/step - loss: 1.8233e-04 - val_loss: 0.0087
# Epoch 120/150
# 33/33 [==============================] - 0s 2ms/step - loss: 1.8611e-04 - val_loss: 0.0080
# Epoch 121/150
# 33/33 [==============================] - 0s 2ms/step - loss: 1.8361e-04 - val_loss: 0.0080
# Epoch 122/150
# 33/33 [==============================] - 0s 2ms/step - loss: 1.8779e-04 - val_loss: 0.0084
# Epoch 123/150
# 33/33 [==============================] - 0s 2ms/step - loss: 1.8559e-04 - val_loss: 0.0081
# Epoch 124/150
# 33/33 [==============================] - 0s 2ms/step - loss: 1.7843e-04 - val_loss: 0.0089
# Epoch 125/150
# 33/33 [==============================] - 0s 2ms/step - loss: 1.8811e-04 - val_loss: 0.0087
# Epoch 126/150
# 33/33 [==============================] - 0s 2ms/step - loss: 1.8712e-04 - val_loss: 0.0087
# Epoch 127/150
# 33/33 [==============================] - 0s 2ms/step - loss: 1.9309e-04 - val_loss: 0.0085
# Epoch 128/150
# 33/33 [==============================] - 0s 3ms/step - loss: 1.7270e-04 - val_loss: 0.0077
# Epoch 129/150
# 33/33 [==============================] - 0s 4ms/step - loss: 1.7527e-04 - val_loss: 0.0082
# Epoch 130/150
# 33/33 [==============================] - 0s 3ms/step - loss: 1.6962e-04 - val_loss: 0.0081
# Epoch 131/150
# 33/33 [==============================] - 0s 2ms/step - loss: 1.7952e-04 - val_loss: 0.0089
# Epoch 132/150
# 33/33 [==============================] - 0s 2ms/step - loss: 1.7281e-04 - val_loss: 0.0087
# Epoch 133/150
# 33/33 [==============================] - 0s 2ms/step - loss: 1.6745e-04 - val_loss: 0.0080
# Epoch 134/150
# 33/33 [==============================] - 0s 2ms/step - loss: 1.9536e-04 - val_loss: 0.0090
# Epoch 135/150
# 33/33 [==============================] - 0s 2ms/step - loss: 1.9510e-04 - val_loss: 0.0079
# Epoch 136/150
# 33/33 [==============================] - 0s 3ms/step - loss: 1.6047e-04 - val_loss: 0.0083
# Epoch 137/150
# 33/33 [==============================] - 0s 2ms/step - loss: 1.6999e-04 - val_loss: 0.0082
# Epoch 138/150
# 33/33 [==============================] - 0s 2ms/step - loss: 1.5826e-04 - val_loss: 0.0078
# Epoch 139/150
# 33/33 [==============================] - 0s 2ms/step - loss: 1.6307e-04 - val_loss: 0.0082
# Epoch 140/150
# 33/33 [==============================] - 0s 3ms/step - loss: 1.6452e-04 - val_loss: 0.0081
# Epoch 141/150
# 33/33 [==============================] - 0s 2ms/step - loss: 1.6695e-04 - val_loss: 0.0086
# Epoch 142/150
# 33/33 [==============================] - 0s 2ms/step - loss: 1.5817e-04 - val_loss: 0.0078
# Epoch 143/150
# 33/33 [==============================] - 0s 2ms/step - loss: 1.5458e-04 - val_loss: 0.0085
# Epoch 144/150
# 33/33 [==============================] - 0s 2ms/step - loss: 1.5702e-04 - val_loss: 0.0081
# Epoch 145/150
# 33/33 [==============================] - 0s 2ms/step - loss: 1.5508e-04 - val_loss: 0.0083
# Epoch 146/150
# 33/33 [==============================] - 0s 2ms/step - loss: 1.5930e-04 - val_loss: 0.0087
# Epoch 147/150
# 33/33 [==============================] - 0s 2ms/step - loss: 1.5295e-04 - val_loss: 0.0080
# Epoch 148/150
# 33/33 [==============================] - 0s 2ms/step - loss: 1.5635e-04 - val_loss: 0.0081
# Epoch 149/150
# 33/33 [==============================] - 0s 2ms/step - loss: 1.5322e-04 - val_loss: 0.0083
# Epoch 150/150
# 33/33 [==============================] - 0s 2ms/step - loss: 1.4936e-04 - val_loss: 0.0086
# 42/42 [==============================] - 0s 756us/step

# %%
# Build the LSTM model
model = Sequential()
model.add(LSTM(50, return_sequences=True, input_shape=(sequence_length, len(include))))
model.add(LSTM(50, return_sequences=False))
model.add(Dense(25))
model.add(Dense(1))

model.compile(optimizer='adam', loss='mean_squared_error')
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm (LSTM)                 (None, 5, 50)             12200
#
#  lstm_1 (LSTM)               (None, 50)                20200
#
#  dense_6 (Dense)             (None, 25)                1275
#
#  dense_7 (Dense)             (None, 1)                 26
#
# =================================================================
# Total params: 33701 (131.64 KB)
# Trainable params: 33701 (131.64 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
model.fit(X_train, y_train, batch_size=64, epochs=150)
# Out:
# Epoch 1/150
# 21/21 [==============================] - 3s 4ms/step - loss: 0.0241
# Epoch 2/150
# 21/21 [==============================] - 0s 4ms/step - loss: 0.0052
# Epoch 3/150
# 21/21 [==============================] - 0s 4ms/step - loss: 0.0033
# Epoch 4/150
# 21/21 [==============================] - 0s 5ms/step - loss: 0.0021
# Epoch 5/150
# 21/21 [==============================] - 0s 3ms/step - loss: 0.0015
# Epoch 6/150
# 21/21 [==============================] - 0s 3ms/step - loss: 0.0012
# Epoch 7/150
# 21/21 [==============================] - 0s 4ms/step - loss: 0.0012
# Epoch 8/150
# 21/21 [==============================] - 0s 4ms/step - loss: 0.0010
# Epoch 9/150
# 21/21 [==============================] - 0s 3ms/step - loss: 9.7843e-04
# Epoch 10/150
# 21/21 [==============================] - 0s 4ms/step - loss: 0.0010
# Epoch 11/150
# 21/21 [==============================] - 0s 4ms/step - loss: 0.0010
# Epoch 12/150
# 21/21 [==============================] - 0s 4ms/step - loss: 0.0012
# Epoch 13/150
# 21/21 [==============================] - 0s 4ms/step - loss: 0.0012
# Epoch 14/150
# 21/21 [==============================] - 0s 4ms/step - loss: 9.1198e-04
# Epoch 15/150
# 21/21 [==============================] - 0s 3ms/step - loss: 8.4839e-04
# Epoch 16/150
# 21/21 [==============================] - 0s 3ms/step - loss: 9.2613e-04
# Epoch 17/150
# 21/21 [==============================] - 0s 3ms/step - loss: 9.1904e-04
# Epoch 18/150
# 21/21 [==============================] - 0s 3ms/step - loss: 8.6802e-04
# Epoch 19/150
# 21/21 [==============================] - 0s 3ms/step - loss: 8.7747e-04
# Epoch 20/150
# 21/21 [==============================] - 0s 3ms/step - loss: 8.9561e-04
# Epoch 21/150
# 21/21 [==============================] - 0s 3ms/step - loss: 7.9815e-04
# Epoch 22/150
# 21/21 [==============================] - 0s 3ms/step - loss: 8.4893e-04
# Epoch 23/150
# 21/21 [==============================] - 0s 4ms/step - loss: 7.7126e-04
# Epoch 24/150
# 21/21 [==============================] - 0s 3ms/step - loss: 8.0795e-04
# Epoch 25/150
# 21/21 [==============================] - 0s 3ms/step - loss: 8.1364e-04
# Epoch 26/150
# 21/21 [==============================] - 0s 3ms/step - loss: 7.5758e-04
# Epoch 27/150
# 21/21 [==============================] - 0s 3ms/step - loss: 7.6973e-04
# Epoch 28/150
# 21/21 [==============================] - 0s 4ms/step - loss: 8.3505e-04
# Epoch 29/150
# 21/21 [==============================] - 0s 3ms/step - loss: 9.1592e-04
# Epoch 30/150
# 21/21 [==============================] - 0s 4ms/step - loss: 8.7170e-04
# Epoch 31/150
# 21/21 [==============================] - 0s 3ms/step - loss: 7.4929e-04
# Epoch 32/150
# 21/21 [==============================] - 0s 3ms/step - loss: 8.4938e-04
# Epoch 33/150
# 21/21 [==============================] - 0s 3ms/step - loss: 0.0011
# Epoch 34/150
# 21/21 [==============================] - 0s 4ms/step - loss: 7.5463e-04
# Epoch 35/150
# 21/21 [==============================] - 0s 4ms/step - loss: 7.0288e-04
# Epoch 36/150
# 21/21 [==============================] - 0s 4ms/step - loss: 7
# 21/21 [==============================] - 0s 3ms/step - loss: 3.6257e-04
# Epoch 150/150
# 21/21 [==============================] - 0s 4ms/step - loss: 3.7201e-04

# %%
# Predict values
predictions = model.predict(X_test)
predictions = scaler.inverse_transform(np.concatenate((predictions, np.zeros((predictions.shape[0], len(include)-1))), axis=1))[:, 0]

# Slice the actual prices to align with the predictions
actual_prices_aligned = df.loc[start_date_testing:end_date_testing, CLOSE][-len(predictions):]
predictions = pd.DataFrame(predictions, index=actual_prices_aligned.index, columns=['Predicted_Close'])

# Convert actual_prices_aligned to a DataFrame
actual_prices_aligned_df = pd.DataFrame(actual_prices_aligned, columns=[CLOSE])

# Calculating the logarithm of predictions and then the logarithmic difference
actual_prices_aligned_df['Predicted_Close'] = predictions
actual_prices_aligned_df['Predicted_Close'] = np.log(actual_prices_aligned_df['Predicted_Close'])
log_diff_predicted = actual_prices_aligned_df['Predicted_Close'].diff().fillna(0)
log_diff_actual = pd.DataFrame(df["Log_Diff_Close"], index=actual_prices_aligned.index, columns=['Log_Diff_Close'])
# Out:
# 5/5 [==============================] - 1s 2ms/step

# %%
prediction_df = pd.concat([log_diff_actual, log_diff_predicted], axis=1)
prediction_df.rename(columns={'Log_Diff_Close': 'Actual Log Diff Close', 'Predicted Close': 'Predicted Log Diff Close'}, inplace=True)
output_path = os.path.join(os.getcwd(), '../../data/output', "prediction_"+CLOSE+".xlsx")
prediction_df.to_excel(output_path, index=False)

prediction_df
# Out:
#             Actual Log Diff Close  Predicted_Close
# date
# 2022-09-08               0.001395         0.000000
# 2022-09-09               0.100396         0.000614
# 2022-09-12               0.047346         0.061528
# 2022-09-13              -0.104497         0.052149
# 2022-09-14               0.002631        -0.046887
# ...                           ...              ...
# 2023-03-20               0.011681         0.063270
# 2023-03-21               0.013918         0.031912
# 2023-03-22              -0.030875         0.027677
# 2023-03-23               0.037610        -0.016523
# 2023-03-24              -0.030171         0.014109
#
# [142 rows x 2 columns]

# %%
money = 10000
money_buy_and_hold = 10000
money_evolution = []
money_evolution_buy_and_hold = []
backtest_values = []
for i in range(len(log_diff_predicted)):
    money_buy_and_hold = money_buy_and_hold * (1 + log_diff_actual.iloc[i][0])
    money_evolution_buy_and_hold.append(money_buy_and_hold)
    if log_diff_predicted[i] >= 0:
        money = money * (1 + log_diff_actual.iloc[i][0])
    else:
        money = money * (1 - log_diff_actual.iloc[i][0])
    money_evolution.append(money)
    cur_date = log_diff_actual.index[i].strftime("%Y-%m-%d")
    cur_rendement_predit = log_diff_predicted.iloc[i]
    cur_vol_empirique = "?"
    cur_prediction = "bull" if log_diff_predicted[i] > 0 else "bear"
    cur_alpha = "100%"
    cur_rendement_observe = log_diff_actual.iloc[i][0]
    cur_valeur_portefeuille = money
    cur_valeur_crypto = df.loc[cur_date, CLOSE]
    backtest_values.append([cur_date, cur_rendement_predit, cur_vol_empirique, cur_prediction, cur_alpha, cur_rendement_observe, cur_valeur_portefeuille, cur_valeur_crypto, money_buy_and_hold])
backtest = pd.DataFrame(backtest_values, columns=['date', 'rendement_predit', 'vol_empirique', 'prediction', 'alpha(expo_crypto)', 'rendement_observe', 'valeur_portefeuille', 'valeur_crypto', 'valeur_portefeuille_buy_and_hold'])
output_path = os.path.join(os.getcwd(), '../../data/output', "backtest_"+CLOSE+".xlsx")
backtest.to_excel(output_path, index=False)
backtest
# Out:
# /tmp/ipykernel_216183/731473146.py:7: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   money_buy_and_hold = money_buy_and_hold * (1 + log_diff_actual.iloc[i][0])
# /tmp/ipykernel_216183/731473146.py:9: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   if log_diff_predicted[i] >= 0:
# /tmp/ipykernel_216183/731473146.py:10: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   money = money * (1 + log_diff_actual.iloc[i][0])
# /tmp/ipykernel_216183/731473146.py:17: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   cur_prediction = "bull" if log_diff_predicted[i] > 0 else "bear"
# /tmp/ipykernel_216183/731473146.py:19: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   cur_rendement_observe = log_diff_actual.iloc[i][0]
# /tmp/ipykernel_216183/731473146.py:12: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   money = money * (1 - log_diff_actual.iloc[i][0])
#            date  rendement_predit vol_empirique prediction alpha(expo_crypto)  \
# 0    2022-09-08          0.000000             ?       bear               100%
# 1    2022-09-09          0.000614             ?       bull               100%
# 2    2022-09-12          0.061528             ?       bull               100%
# 3    2022-09-13          0.052149             ?       bull               100%
# 4    2022-09-14         -0.046887             ?       bear               100%
# ..          ...               ...           ...        ...                ...
# 137  2023-03-20          0.063270             ?       bull               100%
# 138  2023-03-21          0.031912             ?       bull               100%
# 139  2023-03-22          0.027677             ?       bull               100%
# 140  2023-03-23         -0.016523             ?       bear               100%
# 141  2023-03-24          0.014109             ?       bull               100%
#
#      rendement_observe  valeur_portefeuille  valeur_crypto  \
# 0             0.001395         10013.948813       19319.77
# 1             0.100396         11019.311621       21360.11
# 2             0.047346         11541.027523       22395.74
# 3            -0.104497         10335.019803       20173.57
# 4             0.002631         10307.831711       20226.71
# ..                 ...                  ...            ...
# 137           0.011681         14715.489126       27717.01
# 138           0.013918         14920.298055       28105.47
# 139          -0.030875         14459.632323       27250.97
# 140           0.037610         13915.798555       28295.41
# 141          -0.030171         13495.950501       27454.47
#
#      valeur_portefeuille_buy_and_hold
# 0                        10013.948813
# 1                        11019.311621
# 2                        11541.027523
# 3                        10335.019803
# 4                        10362.207895
# ..                                ...
# 137                      13111.505011
# 138                      13293.989826
# 139                      12883.536527
# 140                      13368.092570
# 141                      12964.769136
#
# [142 rows x 9 columns]

# %%
mse = mean_squared_error(actual_prices_aligned, predictions)

# Calculate RMSE
rmse = math.sqrt(mean_squared_error(actual_prices_aligned, predictions))

# Calculate MAE
mae = mean_absolute_error(actual_prices_aligned, predictions)

# Calculate RMSE Log diff
rmse_log = math.sqrt(mean_squared_error(log_diff_actual, log_diff_predicted))

# Calculate MAE Log diff
mae_log = mean_absolute_error(log_diff_actual, log_diff_predicted)

# Convert predictions DataFrame column to a NumPy array and flatten
predictions_array = predictions.iloc[:, 0].to_numpy().flatten()

# Now calculate MAPE
# Ensure actual_prices_aligned is also a NumPy array for consistency
actual_prices_aligned_array = actual_prices_aligned.to_numpy()

mape = np.mean(np.abs((actual_prices_aligned_array - predictions_array) / actual_prices_aligned_array)) * 100

# Handle division by zero or NaN values
mape = np.nan_to_num(mape)


# Ensure actual_prices_aligned and predictions are correctly aligned and are numpy arrays
actual_values = actual_prices_aligned.values
predicted_values = predictions.values

# U-Theil1
u_theil1 = np.sqrt(np.sum(np.square(predicted_values - actual_values)) / np.sum(np.square(np.diff(actual_values))))

# U-Theil2
u_theil2 = (np.sqrt(np.mean(np.square(predicted_values - actual_values))) / np.sqrt(np.mean(np.square(actual_values))))


# Calculate the Dielbod-Mariano
# Error from your model
model_errors = actual_prices_aligned_array - predictions_array

# Error from a naive model (using previous value as prediction)
naive_errors = actual_prices_aligned_array - np.roll(actual_prices_aligned_array, 1)
naive_errors[0] = 0  # handle the first element which doesn't have a previous value
# Difference in errors
error_diff = model_errors - naive_errors

# Mean difference in errors
mean_diff = np.mean(error_diff)

# Variance of the differences
var_diff = np.var(error_diff)

# Number of observations
n = len(error_diff)

# Calculate DM test statistic
dm_stat = mean_diff / np.sqrt(var_diff / n)

absolute_rendement = money_evolution[-1] / 10000 - 1

# using log accuracy 
accuracy = np.sum(np.sign(log_diff_predicted) == np.sign(log_diff_actual.values.flatten())) / len(log_diff_predicted)


data = {
    'Indicator Name': ['Mean Square Error','Root Mean Square Error', 'Mean Absolute Error','Root Mean Square Error (log)', 'Mean Absolute Error (log)', 'Mean Absolute Percentage Error',
                       'U-Theil1 Statistic', 'U-Theil2 Statistic', 'Diebold-Mariano Test', 'Rendement Absolue', 'Accuracy of correct prediction side'],
    'Value': [mse, rmse, mae, rmse_log, mae_log, mape, u_theil1, u_theil2, dm_stat, absolute_rendement, accuracy]
}

table = pd.DataFrame(data)
table['Value'] = table['Value'].apply(lambda x: round(x, 3))


output_path = os.path.join(os.getcwd(), '../../data/output', "performance_"+CLOSE+".xlsx")
table.to_excel(output_path, index=False)
table
# Out:
#                          Indicator Name        Value
# 0                     Mean Square Error  2243454.062
# 1                Root Mean Square Error     1497.816
# 2                   Mean Absolute Error     1272.794
# 3          Root Mean Square Error (log)        0.047
# 4             Mean Absolute Error (log)        0.033
# 5        Mean Absolute Percentage Error        6.272
# 6                    U-Theil1 Statistic       67.668
# 7                    U-Theil2 Statistic        0.210
# 8                  Diebold-Mariano Test       35.591
# 9                     Rendement Absolue        0.350
# 10  Accuracy of correct prediction side        0.451

# %%
plt.figure(figsize=(16, 8))
plt.subplot(2, 1, 1)
plt.plot(money_evolution_buy_and_hold, label='Buy and hold', color='blue')
plt.plot(money_evolution, label='Applied strategy', color='red')
plt.title(f'Current Holdings ({CURRENCY})')
plt.ylabel('Money')
plt.legend()

plt.subplot(2, 1, 2)
plt.plot(log_diff_actual, label='Actual', color='blue')
plt.plot(log_diff_predicted, label='Predicted', color='red')
plt.title(f'Logarithmic Difference')
plt.xlabel('Time')
plt.ylabel('Log Difference')
plt.legend()

plt.show()
