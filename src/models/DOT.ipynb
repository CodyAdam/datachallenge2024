# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import MinMaxScaler
from tensorflow.keras.models import Sequential, Model
from tensorflow.keras.layers import LSTM, Dense, Input
import matplotlib.pyplot as plt
import tensorflow as tf
import random

import os 
from sklearn.metrics import mean_squared_error, mean_absolute_error
import math
# Out:
# WARNING:tensorflow:From c:\Users\codya\AppData\Local\Programs\Python\Python311\Lib\site-packages\keras\src\losses.py:2976: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.

# %%
CURRENCY = "DOT"
CLOSE = f"Close_{CURRENCY}"

seed = random.randint(0, 1000000)
seed = 122751
print(seed)
tf.random.set_seed(seed)
np.random.seed(seed)
random.seed(seed)
# Out:
# 122751

# %%
dataset_pickle = '../../data/federalfinancegestion/dataset.pkl'
df = pd.read_pickle(dataset_pickle)

# Remove all string (object type) columns from the dataset
data_numeric = df.select_dtypes(exclude=['object'])

# Finding the column that closely matches "Close_BTC" in the numeric dataset
close_btc_column_numeric = [col for col in data_numeric.columns if "Close_BTC" in col]

close_btc_column_numeric = close_btc_column_numeric[0]
# Calculate the correlation of all columns with Close_BTC in the numeric dataset
correlation_with_close_btc_numeric = data_numeric.corr()[close_btc_column_numeric].sort_values(ascending=False)

# Extract the top 10 most correlated feature names
top_feature = correlation_with_close_btc_numeric.head(10).index.tolist()
include = top_feature

# %%
# Load data
df.fillna(0, inplace=True)
df['date'] = pd.to_datetime(df['date'])
df.set_index('date', inplace=True)

start_date_training = pd.to_datetime('2017-08-01')
end_date_training = pd.to_datetime('2022-08-31')
start_date_testing = pd.to_datetime('2022-09-01')
end_date_testing = pd.to_datetime('2023-04-30')

# %%
train_df = df.loc[start_date_training:end_date_training]
test_df = df.loc[start_date_testing:end_date_testing]

# %%
# Calculating the logarithmic difference of 'Close'
df['Close_Log'] = np.log(df[CLOSE])  # First, compute the log of 'Close'
df['Log_Diff_Close'] = df['Close_Log'].diff().fillna(0)  # Then compute the difference and handle NaN
# Out:
# c:\Users\codya\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\arraylike.py:396: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)

# %%
# Include features
train = train_df[include].values
test = test_df[include].values

# %%
# Normalize the data
scaler = MinMaxScaler(feature_range=(0, 1))
train_scaled = scaler.fit_transform(train)
test_scaled = scaler.transform(test)

# %%
# # # SDAE
input_layer = Input(shape=(len(include),))
encoded = Dense(64, activation='relu')(input_layer)
encoded = Dense(32, activation='relu')(encoded)
encoded = Dense(16, activation='relu')(encoded)

decoded = Dense(32, activation='relu')(encoded)
decoded = Dense(64, activation='relu')(decoded)
decoded = Dense(len(include), activation='sigmoid')(decoded)

autoencoder = Model(input_layer, decoded)
autoencoder.compile(optimizer='adam', loss='mse')

# Train the autoencoder
autoencoder.fit(train_scaled, train_scaled, epochs=150, batch_size=32, shuffle=True, validation_split=0.2)

# Get the encoded representation of the data
encoded_features = autoencoder.predict(train_scaled)

def create_sequences(data, sequence_length):
    xs, ys = [], []
    for i in range(len(data) - sequence_length):
        x = data[i:(i + sequence_length), :]
        y = data[i + sequence_length, 0]
        xs.append(x)
        ys.append(y)
    return np.array(xs), np.array(ys)

sequence_length = 5  # Number of days used to predict the next day
X_train, y_train = create_sequences(train_scaled, sequence_length)
X_test, y_test = create_sequences(test_scaled, sequence_length)

# Reshape inputs for LSTM [samples, time steps, features]
X_train = np.reshape(X_train, (X_train.shape[0], X_train.shape[1], len(include)))
X_test = np.reshape(X_test, (X_test.shape[0], X_test.shape[1], len(include)))
# Out:
# WARNING:tensorflow:From c:\Users\codya\AppData\Local\Programs\Python\Python311\Lib\site-packages\keras\src\backend.py:1398: The name tf.executing_eagerly_outside_functions is deprecated. Please use tf.compat.v1.executing_eagerly_outside_functions instead.
# WARNING:tensorflow:From c:\Users\codya\AppData\Local\Programs\Python\Python311\Lib\site-packages\keras\src\optimizers\__init__.py:309: The name tf.train.Optimizer is deprecated. Please use tf.compat.v1.train.Optimizer instead.
#
# Epoch 1/150
# WARNING:tensorflow:From c:\Users\codya\AppData\Local\Programs\Python\Python311\Lib\site-packages\keras\src\utils\tf_utils.py:492: The name tf.ragged.RaggedTensorValue is deprecated. Please use tf.compat.v1.ragged.RaggedTensorValue instead.
#
# 33/33 [==============================] - 1s 8ms/step - loss: 0.1212 - val_loss: 0.0905
# Epoch 2/150
# 33/33 [==============================] - 0s 3ms/step - loss: 0.0340 - val_loss: 0.0543
# Epoch 3/150
# 33/33 [==============================] - 0s 2ms/step - loss: 0.0104 - val_loss: 0.0210
# Epoch 4/150
# 33/33 [==============================] - 0s 2ms/step - loss: 0.0070 - val_loss: 0.0159
# Epoch 5/150
# 33/33 [==============================] - 0s 2ms/step - loss: 0.0052 - val_loss: 0.0147
# Epoch 6/150
# 33/33 [==============================] - 0s 2ms/step - loss: 0.0041 - val_loss: 0.0142
# Epoch 7/150
# 33/33 [==============================] - 0s 2ms/step - loss: 0.0036 - val_loss: 0.0136
# Epoch 8/150
# 33/33 [==============================] - 0s 2ms/step - loss: 0.0032 - val_loss: 0.0141
# Epoch 9/150
# 33/33 [==============================] - 0s 2ms/step - loss: 0.0028 - val_loss: 0.0137
# Epoch 10/150
# 33/33 [==============================] - 0s 2ms/step - loss: 0.0024 - val_loss: 0.0132
# Epoch 11/150
# 33/33 [==============================] - 0s 3ms/step - loss: 0.0021 - val_loss: 0.0130
# Epoch 12/150
# 33/33 [==============================] - 0s 3ms/step - loss: 0.0019 - val_loss: 0.0130
# Epoch 13/150
# 33/33 [==============================] - 0s 4ms/step - loss: 0.0016 - val_loss: 0.0126
# Epoch 14/150
# 33/33 [==============================] - 0s 3ms/step - loss: 0.0014 - val_loss: 0.0119
# Epoch 15/150
# 33/33 [==============================] - 0s 3ms/step - loss: 0.0013 - val_loss: 0.0119
# Epoch 16/150
# 33/33 [==============================] - 0s 3ms/step - loss: 0.0012 - val_loss: 0.0123
# Epoch 17/150
# 33/33 [==============================] - 0s 3ms/step - loss: 0.0012 - val_loss: 0.0110
# Epoch 18/150
# 33/33 [==============================] - 0s 5ms/step - loss: 0.0011 - val_loss: 0.0111
# Epoch 19/150
# 33/33 [==============================] - 0s 3ms/step - loss: 0.0010 - val_loss: 0.0108
# Epoch 20/150
# 33/33 [==============================] - 0s 3ms/step - loss: 0.0010 - val_loss: 0.0120
# Epoch 21/150
# 33/33 [==============================] - 0s 2ms/step - loss: 9.6384e-04 - val_loss: 0.0108
# Epoch 22/150
# 33/33 [==============================] - 0s 3ms/step - loss: 9.1985e-04 - val_loss: 0.0111
# Epoch 23/150
# 33/33 [==============================] - 0s 4ms/step - loss: 8.9167e-04 - val_loss: 0.0112
# Epoch 24/150
# 33/33 [==============================] - 0s 2ms/step - loss: 8.7055e-04 - val_loss: 0.0108
# Epoch 25/150
# 33/33 [==============================] - 0s 3ms/step - loss: 8.2774e-04 - val_loss: 0.0106
# Epoch 26/150
# 33/33 [==============================] - 0s 3ms/step - loss: 8.0012e-04 - val_loss: 0.0107
# Epoch 27/150
# 33/33 [==============================] - 0s 2ms/step - loss: 8.1073e-04 - val_loss: 0.0098
# Epoch 28/150
# 33/33 [==============================] - 0s 2ms/step - loss: 7.5846e-04 - val_loss: 0.0106
# Epoch 29/150
# 33/33 [==============================] - 0s 3ms/step - loss: 7.0618e-04 - val_loss: 0.0102
# Epoch 30/150
# 33/33 [==============================] - 0s 3ms/step - loss: 6.8114e-04 - val_loss: 0.0100
# Epoch 31/150
# 33/33 [==============================] - 0s 3ms/step - loss: 6.4546e-04 - val_loss: 0.0102
# Epoch 32/150
# 33/33 [==============================] - 0s 3ms/step - loss: 6.2936e-04 - val_loss: 0.0106
# Epoch 33/150
# 33/33 [==============================] - 0s 3ms/step - loss: 5.8980e-04 - val_loss: 0.0097
# Epoch 34/150
# 33/33 [==============================] - 0s 3ms/step - loss: 5.5331e-04 - val_loss: 0.0092
# Epoch 35/150
# 33/33 [==============================] - 0s 3ms/step - loss: 5.2970e-04 - val_loss: 0.0095
# Epoch 36/150
# 33/33 [==============================] - 0s 3ms/step - loss: 5.1025e-04 - val_loss: 0.0108
# Epoch 37/150
# 33/33 [==============================] - 0s 3ms/step - loss: 4.8364e-04 - val_loss: 0.0103
# Epoch 38/150
# 33/33 [==============================] - 0s 3ms/step - loss: 4.8407e-04 - val_loss: 0.0091
# Epoch 39/150
# 33/33 [==============================] - 0s 2ms/step - loss: 4.5632e-04 - val_loss: 0.0100
# Epoch 40/150
# 33/33 [==============================] - 0s 2ms/step - loss: 4.2619e-04 - val_loss: 0.0093
# Epoch 41/150
# 33/33 [==============================] - 0s 2ms/step - loss: 4.1461e-04 - val_loss: 0.0086
# Epoch 42/150
# 33/33 [==============================] - 0s 3ms/step - loss: 4.2562e-04 - val_loss: 0.0102
# Epoch 43/150
# 33/33 [==============================] - 0s 4ms/step - loss: 4.1660e-04 - val_loss: 0.0095
# Epoch 44/150
# 33/33 [==============================] - 0s 3ms/step - loss: 3.8619e-04 - val_loss: 0.0087
# Epoch 45/150
# 33/33 [==============================] - 0s 2ms/step - loss: 3.8474e-04 - val_loss: 0.0090
# Epoch 46/150
# 33/33 [==============================] - 0s 2ms/step - loss: 3.7827e-04 - val_loss: 0.0087
# Epoch 47/150
# 33/33 [==============================] - 0s 3ms/step - loss: 3.7673e-04 - val_loss: 0.0088
# Epoch 48/150
# 33/33 [==============================] - 0s 4ms/step - loss: 3.6345e-04 - val_loss: 0.0085
# Epoch 49/150
# 33/33 [==============================] - 0s 6ms/step - loss: 3.5277e-04 - val_loss: 0.0086
# Epoch 50/150
# 33/33 [==============================] - 0s 5ms/step - loss: 3.4255e-04 - val_loss: 0.0086
# Epoch 51/150
# 33/33 [==============================] - 0s 5ms/step - loss: 3.4050e-04 - val_loss: 0.0083
# Epoch 52/150
# 33/33 [==============================] - 0s 4ms/step - loss: 3.3805e-04 - val_loss: 0.0098
# Epoch 53/150
# 33/33 [==============================] - 0s 4ms/step - loss: 3.2869e-04 - val_loss: 0.0084
# Epoch 54/150
# 33/33 [==============================] - 0s 3ms/step - loss: 3.2230e-04 - val_loss: 0.0086
# Epoch 55/150
# 33/33 [==============================] - 0s 3ms/step - loss: 3.2286e-04 - val_loss: 0.0086
# Epoch 56/150
# 33/33 [==============================] - 0s 3ms/step - loss: 3.1315e-04 - val_loss: 0.0084
# Epoch 57/150
# 33/33 [==============================] - 0s 3ms/step - loss: 3.1112e-04 - val_loss: 0.0077
# Epoch 58/150
# 33/33 [==============================] - 0s 4ms/step - loss: 3.0427e-04 - val_loss: 0.0081
# Epoch 59/150
# 33/33 [==============================] - 0s 5ms/step - loss: 3.0827e-04 - val_loss: 0.0079
# Epoch 60/150
# 33/33 [==============================] - 0s 3ms/step - loss: 2.9911e-04 - val_loss: 0.0084
# Epoch 61/150
# 33/33 [==============================] - 0s 4ms/step - loss: 3.0220e-04 - val_loss: 0.0087
# Epoch 62/150
# 33/33 [==============================] - 0s 4ms/step - loss: 2.9110e-04 - val_loss: 0.0082
# Epoch 63/150
# 33/33 [==============================] - 0s 3ms/step - loss: 2.8072e-04 - val_loss: 0.0082
# Epoch 64/150
# 33/33 [==============================] - 0s 2ms/step - loss: 2.8888e-04 - val_loss: 0.0084
# Epoch 65/150
# 33/33 [==============================] - 0s 3ms/step - loss: 2.7579e-04 - val_loss: 0.0085
# Epoch 66/150
# 33/33 [==============================] - 0s 2ms/step - loss: 2.7551e-04 - val_loss: 0.0085
# Epoch 67/150
# 33/33 [==============================] - 0s 2ms/step - loss: 2.6786e-04 - val_loss: 0.0082
# Epoch 68/150
# 33/33 [==============================] - 0s 2ms/step - loss: 2.6386e-04 - val_loss: 0.0082
# Epoch 69/150
# 33/33 [==============================] - 0s 3ms/step - loss: 2.5932e-04 - val_loss: 0.0079
# Epoch 70/150
# 33/33 [==============================] - 0s 3ms/step - loss: 2.6639e-04 - val_loss: 0.0084
# Epoch 71/150
# 33/33 [==============================] - 0s 3ms/step - loss: 2.5879e-04 - val_loss: 0.0085
# Epoch 72/150
# 33/33 [==============================] - 0s 2ms/step - loss: 2.6112e-04 - val_loss: 0.0088
# Epoch 73/150
# 33/33 [==============================] - 0s 3ms/step - loss: 2.5270e-04 - val_loss: 0.0080
# Epoch 74/150
# 33/33 [==============================] - 0s 3ms/step - loss: 2.5175e-04 - val_loss: 0.0082
# Epoch 75/150
# 33/33 [==============================] - 0s 3ms/step - loss: 2.5215e-04 - val_loss: 0.0090
# Epoch 76/150
# 33/33 [==============================] - 0s 3ms/step - loss: 2.5939e-04 - val_loss: 0.0080
# Epoch 77/150
# 33/33 [==============================] - 0s 3ms/step - loss: 2.5012e-04 - val_loss: 0.0075
# Epoch 78/150
# 33/33 [==============================] - 0s 4ms/step - loss: 2.4430e-04 - val_loss: 0.0085
# Epoch 79/150
# 33/33 [==============================] - 0s 3ms/step - loss: 2.3969e-04 - val_loss: 0.0081
# Epoch 80/150
# 33/33 [==============================] - 0s 2ms/step - loss: 2.3803e-04 - val_loss: 0.0086
# Epoch 81/150
# 33/33 [==============================] - 0s 3ms/step - loss: 2.4452e-04 - val_loss: 0.0085
# Epoch 82/150
# 33/33 [==============================] - 0s 3ms/step - loss: 2.3858e-04 - val_loss: 0.0080
# Epoch 83/150
# 33/33 [==============================] - 0s 2ms/step - loss: 2.3465e-04 - val_loss: 0.0087
# Epoch 84/150
# 33/33 [==============================] - 0s 2ms/step - loss: 2.3594e-04 - val_loss: 0.0082
# Epoch 85/150
# 33/33 [==============================] - 0s 3ms/step - loss: 2.3345e-04 - val_loss: 0.0086
# Epoch 86/150
# 33/33 [==============================] - 0s 3ms/step - loss: 2.2919e-04 - val_loss: 0.0078
# Epoch 87/150
# 33/33 [==============================] - 0s 3ms/step - loss: 2.2609e-04 - val_loss: 0.0085
# Epoch 88/150
# 33/33 [==============================] - 0s 2ms/step - loss: 2.3068e-04 - val_loss: 0.0080
# Epoch 89/150
# 33/33 [==============================] - 0s 2ms/step - loss: 2.4051e-04 - val_loss: 0.0083
# Epoch 90/150
# 33/33 [==============================] - 0s 2ms/step - loss: 2.3802e-04 - val_loss: 0.0079
# Epoch 91/150
# 33/33 [==============================] - 0s 2ms/step - loss: 2.1573e-04 - val_loss: 0.0071
# Epoch 92/150
# 33/33 [==============================] - 0s 2ms/step - loss: 2.2069e-04 - val_loss: 0.0081
# Epoch 93/150
# 33/33 [==============================] - 0s 2ms/step - loss: 2.3374e-04 - val_loss: 0.0075
# Epoch 94/150
# 33/33 [==============================] - 0s 2ms/step - loss: 2.3273e-04 - val_loss: 0.0083
# Epoch 95/150
# 33/33 [==============================] - 0s 3ms/step - loss: 2.2208e-04 - val_loss: 0.0084
# Epoch 96/150
# 33/33 [==============================] - 0s 2ms/step - loss: 2.1641e-04 - val_loss: 0.0082
# Epoch 97/150
# 33/33 [==============================] - 0s 3ms/step - loss: 2.0491e-04 - val_loss: 0.0086
# Epoch 98/150
# 33/33 [==============================] - 0s 2ms/step - loss: 2.1172e-04 - val_loss: 0.0073
# Epoch 99/150
# 33/33 [==============================] - 0s 3ms/step - loss: 2.3521e-04 - val_loss: 0.0082
# Epoch 100/150
# 33/33 [==============================] - 0s 3ms/step - loss: 2.1615e-04 - val_loss: 0.0083
# Epoch 101/150
# 33/33 [==============================] - 0s 2ms/step - loss: 1.9903e-04 - val_loss: 0.0081
# Epoch 102/150
# 33/33 [==============================] - 0s 2ms/step - loss: 1.9563e-04 - val_loss: 0.0086
# Epoch 103/150
# 33/33 [==============================] - 0s 3ms/step - loss: 1.9869e-04 - val_loss: 0.0083
# Epoch 104/150
# 33/33 [==============================] - 0s 3ms/step - loss: 1.9985e-04 - val_loss: 0.0087
# Epoch 105/150
# 33/33 [==============================] - 0s 3ms/step - loss: 2.0477e-04 - val_loss: 0.0080
# Epoch 106/150
# 33/33 [==============================] - 0s 2ms/step - loss: 1.8950e-04 - val_loss: 0.0085
# Epoch 107/150
# 33/33 [==============================] - 0s 2ms/step - loss: 2.0299e-04 - val_loss: 0.0081
# Epoch 108/150
# 33/33 [==============================] - 0s 3ms/step - loss: 1.9421e-04 - val_loss: 0.0083
# Epoch 109/150
# 33/33 [==============================] - 0s 3ms/step - loss: 1.9307e-04 - val_loss: 0.0082
# Epoch 110/150
# 33/33 [==============================] - 0s 4ms/step - loss: 1.8547e-04 - val_loss: 0.0079
# Epoch 111/150
# 33/33 [==============================] - 0s 4ms/step - loss: 1.8383e-04 - val_loss: 0.0080
# Epoch 112/150
# 33/33 [==============================] - 0s 3ms/step - loss: 1.8572e-04 - val_loss: 0.0081
# Epoch 113/150
# 33/33 [==============================] - 0s 3ms/step - loss: 1.8544e-04 - val_loss: 0.0083
# Epoch 114/150
# 33/33 [==============================] - 0s 3ms/step - loss: 1.9539e-04 - val_loss: 0.0087
# Epoch 115/150
# 33/33 [==============================] - 0s 3ms/step - loss: 1.9066e-04 - val_loss: 0.0083
# Epoch 116/150
# 33/33 [==============================] - 0s 2ms/step - loss: 1.8638e-04 - val_loss: 0.0083
# Epoch 117/150
# 33/33 [==============================] - 0s 3ms/step - loss: 1.8432e-04 - val_loss: 0.0087
# Epoch 118/150
# 33/33 [==============================] - 0s 3ms/step - loss: 1.8386e-04 - val_loss: 0.0081
# Epoch 119/150
# 33/33 [==============================] - 0s 3ms/step - loss: 1.7805e-04 - val_loss: 0.0084
# Epoch 120/150
# 33/33 [==============================] - 0s 3ms/step - loss: 1.7766e-04 - val_loss: 0.0079
# Epoch 121/150
# 33/33 [==============================] - 0s 2ms/step - loss: 1.8361e-04 - val_loss: 0.0080
# Epoch 122/150
# 33/33 [==============================] - 0s 3ms/step - loss: 1.8779e-04 - val_loss: 0.0084
# Epoch 123/150
# 33/33 [==============================] - 0s 3ms/step - loss: 2.1702e-04 - val_loss: 0.0078
# Epoch 124/150
# 33/33 [==============================] - 0s 3ms/step - loss: 1.7587e-04 - val_loss: 0.0083
# Epoch 125/150
# 33/33 [==============================] - 0s 4ms/step - loss: 1.7296e-04 - val_loss: 0.0082
# Epoch 126/150
# 33/33 [==============================] - 0s 4ms/step - loss: 1.8058e-04 - val_loss: 0.0088
# Epoch 127/150
# 33/33 [==============================] - 0s 4ms/step - loss: 1.8986e-04 - val_loss: 0.0081
# Epoch 128/150
# 33/33 [==============================] - 0s 4ms/step - loss: 1.7270e-04 - val_loss: 0.0077
# Epoch 129/150
# 33/33 [==============================] - 0s 5ms/step - loss: 1.7527e-04 - val_loss: 0.0082
# Epoch 130/150
# 33/33 [==============================] - 0s 4ms/step - loss: 1.6962e-04 - val_loss: 0.0081
# Epoch 131/150
# 33/33 [==============================] - 0s 4ms/step - loss: 1.6518e-04 - val_loss: 0.0087
# Epoch 132/150
# 33/33 [==============================] - 0s 3ms/step - loss: 1.6368e-04 - val_loss: 0.0084
# Epoch 133/150
# 33/33 [==============================] - 0s 3ms/step - loss: 1.6554e-04 - val_loss: 0.0078
# Epoch 134/150
# 33/33 [==============================] - 0s 3ms/step - loss: 1.8424e-04 - val_loss: 0.0083
# Epoch 135/150
# 33/33 [==============================] - 0s 3ms/step - loss: 1.7982e-04 - val_loss: 0.0076
# Epoch 136/150
# 33/33 [==============================] - 0s 3ms/step - loss: 1.6047e-04 - val_loss: 0.0083
# Epoch 137/150
# 33/33 [==============================] - 0s 3ms/step - loss: 1.6087e-04 - val_loss: 0.0080
# Epoch 138/150
# 33/33 [==============================] - 0s 3ms/step - loss: 1.5765e-04 - val_loss: 0.0078
# Epoch 139/150
# 33/33 [==============================] - 0s 3ms/step - loss: 1.5807e-04 - val_loss: 0.0084
# Epoch 140/150
# 33/33 [==============================] - 0s 3ms/step - loss: 1.6452e-04 - val_loss: 0.0081
# Epoch 141/150
# 33/33 [==============================] - 0s 3ms/step - loss: 1.5774e-04 - val_loss: 0.0085
# Epoch 142/150
# 33/33 [==============================] - 0s 3ms/step - loss: 1.5817e-04 - val_loss: 0.0078
# Epoch 143/150
# 33/33 [==============================] - 0s 3ms/step - loss: 1.5458e-04 - val_loss: 0.0085
# Epoch 144/150
# 33/33 [==============================] - 0s 2ms/step - loss: 1.5827e-04 - val_loss: 0.0079
# Epoch 145/150
# 33/33 [==============================] - 0s 4ms/step - loss: 1.4894e-04 - val_loss: 0.0083
# Epoch 146/150
# 33/33 [==============================] - 0s 4ms/step - loss: 1.5159e-04 - val_loss: 0.0083
# Epoch 147/150
# 33/33 [==============================] - 0s 3ms/step - loss: 1.4477e-04 - val_loss: 0.0078
# Epoch 148/150
# 33/33 [==============================] - 0s 3ms/step - loss: 1.5186e-04 - val_loss: 0.0080
# Epoch 149/150
# 33/33 [==============================] - 0s 3ms/step - loss: 1.4384e-04 - val_loss: 0.0079
# Epoch 150/150
# 33/33 [==============================] - 0s 3ms/step - loss: 1.4936e-04 - val_loss: 0.0086
# 42/42 [==============================] - 0s 966us/step

# %%
# Build the LSTM model
model = Sequential()
model.add(LSTM(50, return_sequences=True, input_shape=(sequence_length, len(include))))
model.add(LSTM(50, return_sequences=False))
model.add(Dense(25))
model.add(Dense(1))

model.compile(optimizer='adam', loss='mean_squared_error')
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm (LSTM)                 (None, 5, 50)             12200
#
#  lstm_1 (LSTM)               (None, 50)                20200
#
#  dense_6 (Dense)             (None, 25)                1275
#
#  dense_7 (Dense)             (None, 1)                 26
#
# =================================================================
# Total params: 33701 (131.64 KB)
# Trainable params: 33701 (131.64 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
model.fit(X_train, y_train, batch_size=64, epochs=150)
# Out:
# Epoch 1/150
# 21/21 [==============================] - 5s 5ms/step - loss: 0.0241
# Epoch 2/150
# 21/21 [==============================] - 0s 7ms/step - loss: 0.0052
# Epoch 3/150
# 21/21 [==============================] - 0s 5ms/step - loss: 0.0033
# Epoch 4/150
# 21/21 [==============================] - 0s 5ms/step - loss: 0.0021
# Epoch 5/150
# 21/21 [==============================] - 0s 7ms/step - loss: 0.0015
# Epoch 6/150
# 21/21 [==============================] - 0s 8ms/step - loss: 0.0012
# Epoch 7/150
# 21/21 [==============================] - 0s 9ms/step - loss: 0.0012
# Epoch 8/150
# 21/21 [==============================] - 0s 9ms/step - loss: 0.0010
# Epoch 9/150
# 21/21 [==============================] - 0s 8ms/step - loss: 9.7843e-04
# Epoch 10/150
# 21/21 [==============================] - 0s 8ms/step - loss: 0.0010
# Epoch 11/150
# 21/21 [==============================] - 0s 6ms/step - loss: 0.0010
# Epoch 12/150
# 21/21 [==============================] - 0s 4ms/step - loss: 0.0012
# Epoch 13/150
# 21/21 [==============================] - 0s 4ms/step - loss: 0.0012
# Epoch 14/150
# 21/21 [==============================] - 0s 7ms/step - loss: 9.1198e-04
# Epoch 15/150
# 21/21 [==============================] - 0s 4ms/step - loss: 8.4839e-04
# Epoch 16/150
# 21/21 [==============================] - 0s 4ms/step - loss: 9.2613e-04
# Epoch 17/150
# 21/21 [==============================] - 0s 4ms/step - loss: 9.1904e-04
# Epoch 18/150
# 21/21 [==============================] - 0s 4ms/step - loss: 8.6802e-04
# Epoch 19/150
# 21/21 [==============================] - 0s 4ms/step - loss: 8.7747e-04
# Epoch 20/150
# 21/21 [==============================] - 0s 4ms/step - loss: 8.9561e-04
# Epoch 21/150
# 21/21 [==============================] - 0s 4ms/step - loss: 7.9815e-04
# Epoch 22/150
# 21/21 [==============================] - 0s 4ms/step - loss: 8.4893e-04
# Epoch 23/150
# 21/21 [==============================] - 0s 4ms/step - loss: 7.7126e-04
# Epoch 24/150
# 21/21 [==============================] - 0s 4ms/step - loss: 8.0795e-04
# Epoch 25/150
# 21/21 [==============================] - 0s 4ms/step - loss: 8.1364e-04
# Epoch 26/150
# 21/21 [==============================] - 0s 4ms/step - loss: 7.5758e-04
# Epoch 27/150
# 21/21 [==============================] - 0s 4ms/step - loss: 7.6973e-04
# Epoch 28/150
# 21/21 [==============================] - 0s 4ms/step - loss: 8.3505e-04
# Epoch 29/150
# 21/21 [==============================] - 0s 4ms/step - loss: 9.1592e-04
# Epoch 30/150
# 21/21 [==============================] - 0s 4ms/step - loss: 8.7170e-04
# Epoch 31/150
# 21/21 [==============================] - 0s 4ms/step - loss: 7.4929e-04
# Epoch 32/150
# 21/21 [==============================] - 0s 4ms/step - loss: 8.4938e-04
# Epoch 33/150
# 21/21 [==============================] - 0s 4ms/step - loss: 0.0011
# Epoch 34/150
# 21/21 [==============================] - 0s 4ms/step - loss: 7.5463e-04
# Epoch 35/150
# 21/21 [==============================] - 0s 4ms/step - loss: 7.0288e-04
# Epoch 36/150
# 21/21 [==============================] - 0s 4ms/step - loss: 7.0372e-04
# Epoch 37/150
# 21/21 [==============================] - 0s 4ms/step - loss: 6.9809e-04
# Epoch 38/150
# 21/21 [==============================] - 0s 4ms/step - loss: 6.7464e-04
# Epoch 39/150
# 21/21 [==============================] - 0s 4ms/step - loss: 7.8837e-04
# Epoch 40/150
# 21/21 [==============================] - 0s 4ms/step - loss: 8.3061e-04
# Epoch 41/150
# 21/21 [==============================] - 0s 4ms/step - loss: 6.7300e-04
# Epoch 42/150
# 21/21 [==============================] - 0s 4ms/step - loss: 7.5791e-04
# Epoch 43/150
# 21/21 [==============================] - 0s 4ms/step - loss: 6.9651e-04
# Epoch 44/150
# 21/21 [==============================] - 0s 4ms/step - loss: 6.1366e-04
# Epoch 45/150
# 21/21 [==============================] - 0s 4ms/step - loss: 6.2372e-04
# Epoch 46/150
# 21/21 [==============================] - 0s 4ms/step - loss: 7.6276e-04
# Epoch 47/150
# 21/21 [==============================] - 0s 4ms/step - loss: 6.0428e-04
# Epoch 48/150
# 21/21 [==============================] - 0s 4ms/step - loss: 6.6010e-04
# Epoch 49/150
# 21/21 [==============================] - 0s 4ms/step - loss: 6.2767e-04
# Epoch 50/150
# 21/21 [==============================] - 0s 4ms/step - loss: 7.1235e-04
# Epoch 51/150
# 21/21 [==============================] - 0s 4ms/step - loss: 7.4930e-04
# Epoch 52/150
# 21/21 [==============================] - 0s 4ms/step - loss: 6.8182e-04
# Epoch 53/150
# 21/21 [==============================] - 0s 4ms/step - loss: 6.2473e-04
# Epoch 54/150
# 21/21 [==============================] - 0s 4ms/step - loss: 6.5020e-04
# Epoch 55/150
# 21/21 [==============================] - 0s 4ms/step - loss: 6.5492e-04
# Epoch 56/150
# 21/21 [==============================] - 0s 4ms/step - loss: 6.1511e-04
# Epoch 57/150
# 21/21 [==============================] - 0s 4ms/step - loss: 6.6874e-04
# Epoch 58/150
# 21/21 [==============================] - 0s 4ms/step - loss: 5.9887e-04
# Epoch 59/150
# 21/21 [==============================] - 0s 4ms/step - loss: 5.5956e-04
# Epoch 60/150
# 21/21 [==============================] - 0s 4ms/step - loss: 6.0439e-04
# Epoch 61/150
# 21/21 [==============================] - 0s 4ms/step - loss: 5.1668e-04
# Epoch 62/150
# 21/21 [==============================] - 0s 4ms/step - loss: 5.7773e-04
# Epoch 63/150
# 21/21 [==============================] - 0s 4ms/step - loss: 5.4751e-04
# Epoch 64/150
# 21/21 [==============================] - 0s 4ms/step - loss: 5.5360e-04
# Epoch 65/150
# 21/21 [==============================] - 0s 4ms/step - loss: 5.2889e-04
# Epoch 66/150
# 21/21 [==============================] - 0s 4ms/step - loss: 5.0007e-04
# Epoch 67/150
# 21/21 [==============================] - 0s 5ms/step - loss: 5.3804e-04
# Epoch 68/150
# 21/21 [==============================] - 0s 6ms/step - loss: 5.3421e-04
# Epoch 69/150
# 21/21 [==============================] - 0s 4ms/step - loss: 6.1371e-04
# Epoch 70/150
# 21/21 [==============================] - 0s 4ms/step - loss: 6.7432e-04
# Epoch 71/150
# 21/21 [==============================] - 0s 4ms/step - loss: 5.4371e-04
# Epoch 72/150
# 21/21 [==============================] - 0s 4ms/step - loss: 5.5146e-04
# Epoch 73/150
# 21/21 [==============================] - 0s 4ms/step - loss: 4.9319e-04
# Epoch 74/150
# 21/21 [==============================] - 0s 4ms/step - loss: 4.8278e-04
# Epoch 75/150
# 21/21 [==============================] - 0s 4ms/step - loss: 6.4715e-04
# Epoch 76/150
# 21/21 [==============================] - 0s 4ms/step - loss: 7.0730e-04
# Epoch 77/150
# 21/21 [==============================] - 0s 4ms/step - loss: 5.2227e-04
# Epoch 78/150
# 21/21 [==============================] - 0s 4ms/step - loss: 4.8937e-04
# Epoch 79/150
# 21/21 [==============================] - 0s 4ms/step - loss: 5.7733e-04
# Epoch 80/150
# 21/21 [==============================] - 0s 4ms/step - loss: 5.9739e-04
# Epoch 81/150
# 21/21 [==============================] - 0s 4ms/step - loss: 4.6656e-04
# Epoch 82/150
# 21/21 [==============================] - 0s 4ms/step - loss: 5.0858e-04
# Epoch 83/150
# 21/21 [==============================] - 0s 4ms/step - loss: 4.6799e-04
# Epoch 84/150
# 21/21 [==============================] - 0s 7ms/step - loss: 4.6761e-04
# Epoch 85/150
# 21/21 [==============================] - 0s 5ms/step - loss: 4.8408e-04
# Epoch 86/150
# 21/21 [==============================] - 0s 7ms/step - loss: 4.6713e-04
# Epoch 87/150
# 21/21 [==============================] - 0s 8ms/step - loss: 4.8302e-04
# Epoch 88/150
# 21/21 [==============================] - 0s 7ms/step - loss: 5.3011e-04
# Epoch 89/150
# 21/21 [==============================] - 0s 7ms/step - loss: 7.3241e-04
# Epoch 90/150
# 21/21 [==============================] - 0s 8ms/step - loss: 5.7290e-04
# Epoch 91/150
# 21/21 [==============================] - 0s 5ms/step - loss: 4.6788e-04
# Epoch 92/150
# 21/21 [==============================] - 0s 6ms/step - loss: 4.6951e-04
# Epoch 93/150
# 21/21 [==============================] - 0s 7ms/step - loss: 4.5231e-04
# Epoch 94/150
# 21/21 [==============================] - 0s 4ms/step - loss: 4.4272e-04
# Epoch 95/150
# 21/21 [==============================] - 0s 4ms/step - loss: 4.7132e-04
# Epoch 96/150
# 21/21 [==============================] - 0s 4ms/step - loss: 4.2907e-04
# Epoch 97/150
# 21/21 [==============================] - 0s 4ms/step - loss: 4.1806e-04
# Epoch 98/150
# 21/21 [==============================] - 0s 4ms/step - loss: 4.5062e-04
# Epoch 99/150
# 21/21 [==============================] - 0s 4ms/step - loss: 4.3681e-04
# Epoch 100/150
# 21/21 [==============================] - 0s 4ms/step - loss: 4.4267e-04
# Epoch 101/150
# 21/21 [==============================] - 0s 4ms/step - loss: 4.4014e-04
# Epoch 102/150
# 21/21 [==============================] - 0s 5ms/step - loss: 4.6211e-04
# Epoch 103/150
# 21/21 [==============================] - 0s 5ms/step - loss: 4.1546e-04
# Epoch 104/150
# 21/21 [==============================] - 0s 6ms/step - loss: 4.2437e-04
# Epoch 105/150
# 21/21 [==============================] - 0s 5ms/step - loss: 4.4803e-04
# Epoch 106/150
# 21/21 [==============================] - 0s 4ms/step - loss: 4.4814e-04
# Epoch 107/150
# 21/21 [==============================] - 0s 4ms/step - loss: 4.2992e-04
# Epoch 108/150
# 21/21 [==============================] - 0s 6ms/step - loss: 3.9948e-04
# Epoch 109/150
# 21/21 [==============================] - 0s 4ms/step - loss: 3.9843e-04
# Epoch 110/150
# 21/21 [==============================] - 0s 4ms/step - loss: 4.5193e-04
# Epoch 111/150
# 21/21 [==============================] - 0s 4ms/step - loss: 4.2568e-04
# Epoch 112/150
# 21/21 [==============================] - 0s 4ms/step - loss: 4.1013e-04
# Epoch 113/150
# 21/21 [==============================] - 0s 4ms/step - loss: 4.0638e-04
# Epoch 114/150
# 21/21 [==============================] - 0s 6ms/step - loss: 4.2885e-04
# Epoch 115/150
# 21/21 [==============================] - 0s 6ms/step - loss: 4.2992e-04
# Epoch 116/150
# 21/21 [==============================] - 0s 6ms/step - loss: 5.1375e-04
# Epoch 117/150
# 21/21 [==============================] - 0s 8ms/step - loss: 4.5671e-04
# Epoch 118/150
# 21/21 [==============================] - 0s 4ms/step - loss: 4.5500e-04
# Epoch 119/150
# 21/21 [==============================] - 0s 4ms/step - loss: 3.7892e-04
# Epoch 120/150
# 21/21 [==============================] - 0s 6ms/step - loss: 3.8875e-04
# Epoch 121/150
# 21/21 [==============================] - 0s 4ms/step - loss: 4.0655e-04
# Epoch 122/150
# 21/21 [==============================] - 0s 4ms/step - loss: 4.0494e-04
# Epoch 123/150
# 21/21 [==============================] - 0s 5ms/step - loss: 3.8700e-04
# Epoch 124/150
# 21/21 [==============================] - 0s 4ms/step - loss: 4.0927e-04
# Epoch 125/150
# 21/21 [==============================] - 0s 5ms/step - loss: 4.1522e-04
# Epoch 126/150
# 21/21 [==============================] - 0s 5ms/step - loss: 4.5581e-04
# Epoch 127/150
# 21/21 [==============================] - 0s 4ms/step - loss: 3.8933e-04
# Epoch 128/150
# 21/21 [==============================] - 0s 4ms/step - loss: 5.1587e-04
# Epoch 129/150
# 21/21 [==============================] - 0s 4ms/step - loss: 4.0976e-04
# Epoch 130/150
# 21/21 [==============================] - 0s 4ms/step - loss: 3.9776e-04
# Epoch 131/150
# 21/21 [==============================] - 0s 4ms/step - loss: 4.6730e-04
# Epoch 132/150
# 21/21 [==============================] - 0s 4ms/step - loss: 3.8025e-04
# Epoch 133/150
# 21/21 [==============================] - 0s 4ms/step - loss: 4.5721e-04
# Epoch 134/150
# 21/21 [==============================] - 0s 4ms/step - loss: 4.9514e-04
# Epoch 135/150
# 21/21 [==============================] - 0s 4ms/step - loss: 5.2629e-04
# Epoch 136/150
# 21/21 [==============================] - 0s 4ms/step - loss: 4.0786e-04
# Epoch 137/150
# 21/21 [==============================] - 0s 4ms/step - loss: 3.7201e-04
# Epoch 138/150
# 21/21 [==============================] - 0s 4ms/step - loss: 3.8920e-04
# Epoch 139/150
# 21/21 [==============================] - 0s 4ms/step - loss: 4.4502e-04
# Epoch 140/150
# 21/21 [==============================] - 0s 4ms/step - loss: 3.7793e-04
# Epoch 141/150
# 21/21 [==============================] - 0s 4ms/step - loss: 3.6709e-04
# Epoch 142/150
# 21/21 [==============================] - 0s 4ms/step - loss: 4.0145e-04
# Epoch 143/150
# 21/21 [==============================] - 0s 4ms/step - loss: 3.7213e-04
# Epoch 144/150
# 21/21 [==============================] - 0s 4ms/step - loss: 3.8674e-04
# Epoch 145/150
# 21/21 [==============================] - 0s 4ms/step - loss: 3.8142e-04
# Epoch 146/150
# 21/21 [==============================] - 0s 7ms/step - loss: 3.7391e-04
# Epoch 147/150
# 21/21 [==============================] - 0s 6ms/step - loss: 3.5463e-04
# Epoch 148/150
# 21/21 [==============================] - 0s 5ms/step - loss: 3.5714e-04
# Epoch 149/150
# 21/21 [==============================] - 0s 5ms/step - loss: 3.6257e-04
# Epoch 150/150
# 21/21 [==============================] - 0s 5ms/step - loss: 3.7201e-04

# %%
# Predict values
predictions = model.predict(X_test)
predictions = scaler.inverse_transform(np.concatenate((predictions, np.zeros((predictions.shape[0], len(include)-1))), axis=1))[:, 0]

# Slice the actual prices to align with the predictions
actual_prices_aligned = df.loc[start_date_testing:end_date_testing, CLOSE][-len(predictions):]
predictions = pd.DataFrame(predictions, index=actual_prices_aligned.index, columns=['Predicted_Close'])

# Convert actual_prices_aligned to a DataFrame
actual_prices_aligned_df = pd.DataFrame(actual_prices_aligned, columns=[CLOSE])

# Calculating the logarithm of predictions and then the logarithmic difference
actual_prices_aligned_df['Predicted_Close'] = predictions
actual_prices_aligned_df['Predicted_Close'] = np.log(actual_prices_aligned_df['Predicted_Close'])
log_diff_predicted = actual_prices_aligned_df['Predicted_Close'].diff().fillna(0)
log_diff_actual = pd.DataFrame(df["Log_Diff_Close"], index=actual_prices_aligned.index, columns=['Log_Diff_Close'])
# Out:
# 5/5 [==============================] - 1s 2ms/step

# %%
prediction_df = pd.concat([log_diff_actual, log_diff_predicted], axis=1)
prediction_df.rename(columns={'Log_Diff_Close': 'Actual Log Diff Close', 'Predicted Close': 'Predicted Log Diff Close'}, inplace=True)
output_path = os.path.join(os.getcwd(), '../../data/output', "prediction_"+CLOSE+".xlsx")
prediction_df.to_excel(output_path, index=False)

prediction_df
# Out:
#             Actual Log Diff Close  Predicted_Close
# date
# 2022-09-08               0.026047         0.000000
# 2022-09-09               0.047565         0.000614
# 2022-09-12              -0.011681         0.061528
# 2022-09-13              -0.081567         0.052149
# 2022-09-14               0.021024        -0.046887
# ...                           ...              ...
# 2023-03-20              -0.082817         0.063270
# 2023-03-21               0.043524         0.031912
# 2023-03-22              -0.049946         0.027677
# 2023-03-23               0.043323        -0.016522
# 2023-03-24              -0.048624         0.014109
#
# [142 rows x 2 columns]

# %%
money = 10000
money_buy_and_hold = 10000
money_evolution = []
money_evolution_buy_and_hold = []
backtest_values = []
for i in range(len(log_diff_predicted)):
    money_buy_and_hold = money_buy_and_hold * (1 + log_diff_actual.iloc[i][0])
    money_evolution_buy_and_hold.append(money_buy_and_hold)
    if log_diff_predicted[i] >= 0:
        money = money * (1 + log_diff_actual.iloc[i][0])
    else:
        money = money * (1 - log_diff_actual.iloc[i][0])
    money_evolution.append(money)
    cur_date = log_diff_actual.index[i].strftime("%Y-%m-%d")
    cur_rendement_predit = log_diff_predicted.iloc[i]
    cur_vol_empirique = "?"
    cur_prediction = "bull" if log_diff_predicted[i] > 0 else "bear"
    cur_alpha = "100%"
    cur_rendement_observe = log_diff_actual.iloc[i][0]
    cur_valeur_portefeuille = money
    cur_valeur_crypto = df.loc[cur_date, CLOSE]
    backtest_values.append([cur_date, cur_rendement_predit, cur_vol_empirique, cur_prediction, cur_alpha, cur_rendement_observe, cur_valeur_portefeuille, cur_valeur_crypto])
backtest = pd.DataFrame(backtest_values, columns=['date', 'rendement_predit', 'vol_empirique', 'prediction', 'alpha(expo_crypto)', 'rendement_observe', 'valeur_portefeuille', 'valeur_crypto'])
output_path = os.path.join(os.getcwd(), '../../data/output', "backtest_"+CLOSE+".xlsx")
backtest.to_excel(output_path, index=False)
backtest
# Out:
#            date  rendement_predit vol_empirique prediction alpha(expo_crypto)  \
# 0    2022-09-08          0.000000             ?       bear               100%
# 1    2022-09-09          0.000614             ?       bull               100%
# 2    2022-09-12          0.061528             ?       bull               100%
# 3    2022-09-13          0.052149             ?       bull               100%
# 4    2022-09-14         -0.046887             ?       bear               100%
# ..          ...               ...           ...        ...                ...
# 137  2023-03-20          0.063270             ?       bull               100%
# 138  2023-03-21          0.031912             ?       bull               100%
# 139  2023-03-22          0.027677             ?       bull               100%
# 140  2023-03-23         -0.016522             ?       bear               100%
# 141  2023-03-24          0.014109             ?       bull               100%
#
#      rendement_observe  valeur_portefeuille  valeur_crypto
# 0             0.026047         10260.467089          7.390
# 1             0.047565         10748.507319          7.750
# 2            -0.011681         10622.955514          7.660
# 3            -0.081567          9756.473621          7.060
# 4             0.021024          9551.354497          7.210
# ..                 ...                  ...            ...
# 137          -0.082817         13271.559167          6.092
# 138           0.043524         13849.184260          6.363
# 139          -0.049946         13157.473632          6.053
# 140           0.043323         12587.447052          6.321
# 141          -0.048624         11975.394209          6.021
#
# [142 rows x 8 columns]

# %%
mse = mean_squared_error(actual_prices_aligned, predictions)

# Calculate RMSE
rmse = math.sqrt(mean_squared_error(actual_prices_aligned, predictions))

# Calculate MAE
mae = mean_absolute_error(actual_prices_aligned, predictions)

# Calculate RMSE Log diff
rmse_log = math.sqrt(mean_squared_error(log_diff_actual, log_diff_predicted))

# Calculate MAE Log diff
mae_log = mean_absolute_error(log_diff_actual, log_diff_predicted)

# Convert predictions DataFrame column to a NumPy array and flatten
predictions_array = predictions.iloc[:, 0].to_numpy().flatten()

# Now calculate MAPE
# Ensure actual_prices_aligned is also a NumPy array for consistency
actual_prices_aligned_array = actual_prices_aligned.to_numpy()

mape = np.mean(np.abs((actual_prices_aligned_array - predictions_array) / actual_prices_aligned_array)) * 100

# Handle division by zero or NaN values
mape = np.nan_to_num(mape)


# Ensure actual_prices_aligned and predictions are correctly aligned and are numpy arrays
actual_values = actual_prices_aligned.values
predicted_values = predictions.values

# U-Theil1
u_theil1 = np.sqrt(np.sum(np.square(predicted_values - actual_values)) / np.sum(np.square(np.diff(actual_values))))

# U-Theil2
u_theil2 = (np.sqrt(np.mean(np.square(predicted_values - actual_values))) / np.sqrt(np.mean(np.square(actual_values))))


# Calculate the Dielbod-Mariano
# Error from your model
model_errors = actual_prices_aligned_array - predictions_array

# Error from a naive model (using previous value as prediction)
naive_errors = actual_prices_aligned_array - np.roll(actual_prices_aligned_array, 1)
naive_errors[0] = 0  # handle the first element which doesn't have a previous value
# Difference in errors
error_diff = model_errors - naive_errors

# Mean difference in errors
mean_diff = np.mean(error_diff)

# Variance of the differences
var_diff = np.var(error_diff)

# Number of observations
n = len(error_diff)

# Calculate DM test statistic
dm_stat = mean_diff / np.sqrt(var_diff / n)

absolute_rendement = money_evolution[-1] / 10000 - 1


data = {
    'Indicator Name': ['Mean Square Error','Root Mean Square Error', 'Mean Absolute Error','Root Mean Square Error (log)', 'Mean Absolute Error (log)', 'Mean Absolute Percentage Error',
                       'U-Theil1 Statistic', 'U-Theil2 Statistic', 'Diebold-Mariano Test', 'Rendement Absolue'],
    'Value': [mse, rmse, mae, rmse_log, mae_log, mape, u_theil1, u_theil2, dm_stat, absolute_rendement]
}

table = pd.DataFrame(data)
table['Value'] = table['Value'].apply(lambda x: round(x, 3))


output_path = os.path.join(os.getcwd(), '../../data/output', "performance_"+CLOSE+".xlsx")
table.to_excel(output_path, index=False)
table
# Out:
#                    Indicator Name         Value
# 0               Mean Square Error  3.651146e+08
# 1          Root Mean Square Error  1.910797e+04
# 2             Mean Absolute Error  1.890298e+04
# 3    Root Mean Square Error (log)  5.400000e-02
# 4       Mean Absolute Error (log)  4.100000e-02
# 5  Mean Absolute Percentage Error  3.180756e+05
# 6              U-Theil1 Statistic  8.411528e+05
# 7              U-Theil2 Statistic  3.175381e+03
# 8            Diebold-Mariano Test -8.069600e+01
# 9               Rendement Absolue  1.980000e-01

# %%
plt.figure(figsize=(16, 8))
plt.subplot(2, 1, 1)
plt.plot(money_evolution_buy_and_hold, label='Buy and hold', color='blue')
plt.plot(money_evolution, label='Applied strategy', color='red')
plt.title(f'Current Holdings ({CURRENCY})')
plt.ylabel('Money')
plt.legend()

plt.subplot(2, 1, 2)
plt.plot(log_diff_actual, label='Actual', color='blue')
plt.plot(log_diff_predicted, label='Predicted', color='red')
plt.title(f'Logarithmic Difference')
plt.xlabel('Time')
plt.ylabel('Log Difference')
plt.legend()

plt.show()

# %%
# import pickle

# # dump money_evolution and money_evolution_buy_and_hold
# with open(f'money/money_evolution_{CURRENCY}.pkl', 'wb') as f:
#     pickle.dump(money_evolution, f)
# with open(f'money/money_evolution_buy_and_hold_{CURRENCY}.pkl', 'wb') as f:
#     pickle.dump(money_evolution_buy_and_hold, f)

# # load mone_evoition from pickle file
# with open(f'money/money_evolution_BTC.pkl', 'rb') as f:
#     money_evolution1 = [10000] + pickle.load(f)
# with open(f'money/money_evolution_ETH.pkl', 'rb') as f:
#     money_evolution2 = [10000] + pickle.load(f)

# for i in range(len(money_evolution1)):
#     money_evolution1[i] += money_evolution2[i]

# with open(f'money/money_evolution_buy_and_hold_BTC.pkl', 'rb') as f:
#     money_evolution_buy_and_hold1 = pickle.load(f)
# with open(f'money/money_evolution_buy_and_hold_ETH.pkl', 'rb') as f:
#     money_evolution_buy_and_hold2 = pickle.load(f)

# for i in range(len(money_evolution_buy_and_hold1)):
#     money_evolution_buy_and_hold1[i] += money_evolution_buy_and_hold2[i]

# ## Compute % growth for both evolutions
# growth_buy_and_hold1 = (money_evolution_buy_and_hold1[-1] - money_evolution_buy_and_hold1[0]) / money_evolution_buy_and_hold1[0]
# growth1 = (money_evolution1[-1] - money_evolution1[0]) / money_evolution1[0]
# print(f'Buy and hold growth: {growth_buy_and_hold1*100:.2f}')
# print(f'Applied strategy growth: {growth1*100:.2f}')

# df = pd.DataFrame(money_evolution1, columns=['Investment_Value'])
# TRADING_DAYS_PER_YEAR = 365
# risk_free_rate = 0.01 / TRADING_DAYS_PER_YEAR
# df['daily_returns'] = df['Investment_Value'].pct_change(1)
# excess_returns = df['daily_returns'] - risk_free_rate
# sharpe_ratio = excess_returns.mean() / excess_returns.std()
# sharpe_ratio_annualized = sharpe_ratio * np.sqrt(TRADING_DAYS_PER_YEAR)
# print()

# df = pd.DataFrame(money_evolution_buy_and_hold1, columns=['Investment_Value'])
# TRADING_DAYS_PER_YEAR = 365
# risk_free_rate = 0.01 / TRADING_DAYS_PER_YEAR
# df['daily_returns'] = df['Investment_Value'].pct_change(1)
# excess_returns = df['daily_returns'] - risk_free_rate
# sharpe_ratio = excess_returns.mean() / excess_returns.std()
# sharpe_ratio_annualized = sharpe_ratio * np.sqrt(TRADING_DAYS_PER_YEAR)
# print(sharpe_ratio_annualized)




# plt.figure(figsize=(16, 8))
# plt.subplot(1, 1, 1)
# plt.plot(money_evolution_buy_and_hold1, label='Buy and hold', color='blue')
# plt.plot(money_evolution1, label='Applied strategy', color='red')
# plt.title(f'Two Kings Portfolio')
# plt.ylabel('Money')
# plt.xlabel('Time')
# plt.legend()
